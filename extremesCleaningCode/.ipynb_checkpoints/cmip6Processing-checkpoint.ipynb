# %% [markdown]
# # Initial Set-Up

# %%
import pickle
import pandas as pd
import matplotlib
import os
import re

import collections
import datetime
import time

import geopandas as gpd

import numpy as np

import rasterio

from difflib import get_close_matches

from fuzzywuzzy import process
from fuzzywuzzy import fuzz

import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

import geopandas as gpd

import seaborn as sns

import numpy as np

import scipy

from matplotlib.colors import LogNorm

from sklearn import preprocessing

import dask.dataframe as dd
# Out:
# /Users/brianreed/opt/anaconda3/lib/python3.7/site-packages/dask/dataframe/utils.py:14: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Weather Data
# ## *this is how we process the cmip6Data

# %%
import netCDF4 as nc
import xarray as xr

# %%
file = '../../../../../../../Volumes/backup2/dissData/cmip6Data/hist/pr/pr_day_MIROC6_historical_r7i1p1f1_gn_20100101-20141231.nc'
data = xr.open_dataset(file)   #  nc.Dataset(file)

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1826, bnds: 2, lat: 128, lon: 256)
# Coordinates:
#   * time       (time) datetime64[ns] 2010-01-01T12:00:00 ... 2014-12-31T12:00:00
#   * lat        (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon        (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     pr         (time, lat, lon) float32 ...
# Attributes: (12/44)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  65744.0
#     creation_date:          2019-08-31T00:35:50Z
#     ...                     ...
#     title:                  MIROC6 output prepared for CMIP6
#     variable_id:            pr
#     variant_label:          r7i1p1f1
#     license:                CMIP6 model data produced by MIROC is licensed un...
#     cmor_version:           3.4.0
#     tracking_id:            hdl:21.14100/8d8284eb-fc98-4225-98e3-a395f374b486

# %%
geoHQ = gpd.GeoDataFrame(
    allIG,
    geometry=gpd.points_from_xy(
        allIG["longitude"],
        allIG["latitude"],
    ),
    crs={"init":"EPSG:4326"},
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-315dd3e4baec> in <module>
#       1 geoHQ = gpd.GeoDataFrame(
# ----> 2     allIG,
#       3     geometry=gpd.points_from_xy(
#       4         allIG["longitude"],
#       5         allIG["latitude"],
#
# NameError: name 'allIG' is not defined

# %%
geoHQ['longitude']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c122b3f05dd8> in <module>
# ----> 1 geoHQ['longitude']
#
# NameError: name 'geoHQ' is not defined

# %%
one_point = data["pr"].sel(lat=50, lon=50)

# %%
pd.DataFrame(test.temperature[test.year == 2010]).plot()

# %% [markdown]
# Now go through and make this iterable for the entire list.

# %%
i = 0
data.pr.sel(allIG.iloc[0,:], method='nearest')

# %%
hqPost2010 = geoHQ[geoHQ.archive_version_year > 2010].reset_index()

# %%
start = time.time()



tempsList = list()
for i in range(0,hqPost2010.shape[0]):
    nearbyTemps = temps.sel(hqPost2010.loc[i,['latitude','longitude']], method='nearest')
    
    tempsList.append(list(np.array(nearbyTemps.temperature[nearbyTemps.year == hqPost2010.archive_version_year[i]])))

    if (i%100 == 0):
        print(i)
    
print(time.time() - start)

# %%
outfile =  'data/hqDailyTemperatures.pkl'
with open(outfile, 'wb') as pickle_file:
    pickle.dump(tempsList, pickle_file)

# %% [markdown]
# # Now let's do the percentiles

# %%
baselineName = '../../../../../../../Volumes/backup2/dissData/cmip6Data/hist/mirocHQs_198199.csv'
baseline = pd.read_csv(baselineName)

# %%
baseline.head()
# Out:
#    zipcode variable         value quarter
# 0    44146  pr_hist  5.603128e-06      Q1
# 1    85260  pr_hist  4.505838e-18      Q1
# 2     8876  pr_hist  3.638395e-08      Q1
# 3    60411  pr_hist  1.171563e-05      Q1
# 4    74102  pr_hist  4.505838e-18      Q1

# %%
baseline[baseline.variable == 'tasmax_hist']
# Out:
#            zipcode     variable     value quarter
# 24991061     44146  tasmax_hist  270.2769      Q1
# 24991062     85260  tasmax_hist  292.3866      Q1
# 24991063      8876  tasmax_hist  273.9805      Q1
# 24991064     60411  tasmax_hist  270.4595      Q1
# 24991065     74102  tasmax_hist  285.0438      Q1
# ...            ...          ...       ...     ...
# 105514429    10017  tasmax_hist  274.6280      Q4
# 105514430    55401  tasmax_hist  270.9852      Q4
# 105514431    19087  tasmax_hist  276.1574      Q4
# 105514432    97229  tasmax_hist  277.6618      Q4
# 105514433    30339  tasmax_hist  281.8853      Q4
#
# [52757217 rows x 4 columns]

# %%
quantsPrecip   = baseline[baseline.variable == 'pr_hist'].groupby(['zipcode','variable','quarter']).quantile(.95).reset_index()
quantsPrecip.rename(columns = {'value': 'quantCutoff'}, inplace = True)
quantsPrecip['daysExtreme'] = 4.5

# %%
quantsPrecip.head()
# Out:
#    zipcode variable quarter  quantCutoff  daysExtreme
# 0     1226  pr_hist      Q1     0.000215          4.5
# 1     1226  pr_hist      Q2     0.000275          4.5
# 2     1226  pr_hist      Q3     0.000249          4.5
# 3     1226  pr_hist      Q4     0.000224          4.5
# 4     1434  pr_hist      Q1     0.000239          4.5

# %% [markdown]
# Find number of days above 90F.

# %%
temp = baseline[baseline.variable == 'tasmax_hist']
temp.head()
# Out:
#           zipcode     variable     value quarter
# 24991061    44146  tasmax_hist  270.2769      Q1
# 24991062    85260  tasmax_hist  292.3866      Q1
# 24991063     8876  tasmax_hist  273.9805      Q1
# 24991064    60411  tasmax_hist  270.4595      Q1
# 24991065    74102  tasmax_hist  285.0438      Q1

# %%
temp[temp.]

# %%
quantsTemp = baseline[baseline.variable == 'tasmax_hist']
quantsTemp['daysExtreme'] = 1*(quantsTemp.value > 305.3)
quantsTemp = quantsTemp.groupby(['zipcode', 'variable', 'quarter']).mean().reset_index()
quantsTemp.rename(columns = {'value': 'quantCutoff'}, inplace = True)

quantsTemp.daysExtreme = quantsTemp.daysExtreme*90
quantsTemp.quantCutoff = 305.3


quantsTemp.head()
# Out:
# /Users/brianreed/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    zipcode     variable quarter  quantCutoff  daysExtreme
# 0     1226  tasmax_hist      Q1        305.3     0.000000
# 1     1226  tasmax_hist      Q2        305.3     2.914980
# 2     1226  tasmax_hist      Q3        305.3     8.804348
# 3     1226  tasmax_hist      Q4        305.3     0.000000
# 4     1434  tasmax_hist      Q1        305.3     0.000000

# %%
quants = quantsPrecip.append(quantsTemp)

# %%
quants.head()
# Out:
#    zipcode variable quarter  quantCutoff  daysExtreme
# 0     1226  pr_hist      Q1     0.000215          4.5
# 1     1226  pr_hist      Q2     0.000275          4.5
# 2     1226  pr_hist      Q3     0.000249          4.5
# 3     1226  pr_hist      Q4     0.000224          4.5
# 4     1434  pr_hist      Q1     0.000239          4.5

# %% [markdown]
# And apply them to the next period.

# %%
nextPeriodName = '../../../../../../../Volumes/backup2/dissData/cmip6Data/proj/mirocHQs_202040.csv'
nextPeriod = pd.read_csv(nextPeriodName).drop(columns = ['s'])

# %%
nextPeriod.head()
# Out:
#    zipcode  latitude  longitude variable         value  year quarter
# 0    44146  41.41278  -81.50616  pr_hist  5.541186e-05  2020      Q1
# 1    85260  33.61963 -111.90171  pr_hist  4.853382e-17  2020      Q1
# 2     8876  40.59778  -74.69065  pr_hist  4.139848e-08  2020      Q1
# 3    60411  41.52176  -87.61784  pr_hist  1.024405e-04  2020      Q1
# 4    74102  36.15089  -95.99398  pr_hist  2.608104e-06  2020      Q1

# %%
quants.daysExtreme
# Out:
# 0       4.500000
# 1       4.500000
# 2       4.500000
# 3       4.500000
# 4       4.500000
#           ...
# 8527    0.000000
# 8528    0.000000
# 8529    0.000000
# 8530    0.102975
# 8531    0.000000
# Name: daysExtreme, Length: 17064, dtype: float64

# %%
nextPeriod = nextPeriod.merge(quants)
nextPeriod.head()
# Out:
#    zipcode  latitude  longitude variable     value  year quarter  quantCutoff  \
# 0    44146  41.41278  -81.50616  pr_hist  0.000055  2020      Q1     0.000161
# 1    44146  41.41371  -81.50582  pr_hist  0.000055  2020      Q1     0.000161
# 2    44146  41.41278  -81.50616  pr_hist  0.000002  2020      Q1     0.000161
# 3    44146  41.41371  -81.50582  pr_hist  0.000002  2020      Q1     0.000161
# 4    44146  41.41278  -81.50616  pr_hist  0.000003  2020      Q1     0.000161
#
#    daysExtreme
# 0          4.5
# 1          4.5
# 2          4.5
# 3          4.5
# 4          4.5

# %%
nextPeriod.head()
# Out:
#    zipcode  latitude  longitude variable     value  year quarter  quantCutoff
# 0    44146  41.41278  -81.50616  pr_hist  0.000055  2020      Q1     0.000161
# 1    44146  41.41371  -81.50582  pr_hist  0.000055  2020      Q1     0.000161
# 2    44146  41.41278  -81.50616  pr_hist  0.000002  2020      Q1     0.000161
# 3    44146  41.41371  -81.50582  pr_hist  0.000002  2020      Q1     0.000161
# 4    44146  41.41278  -81.50616  pr_hist  0.000003  2020      Q1     0.000161

# %%
nextPeriod['extreme'] = 1*(nextPeriod.value > nextPeriod.quantCutoff)

# %%
# nextPeriod.to_csv("../../data/companyData/nextPeriodExtremes.csv")

# %%
nextPeriod.head()
# Out:
#    zipcode  latitude  longitude variable     value  year quarter  quantCutoff  \
# 0    44146  41.41278  -81.50616  pr_hist  0.000055  2020      Q1     0.000161
# 1    44146  41.41371  -81.50582  pr_hist  0.000055  2020      Q1     0.000161
# 2    44146  41.41278  -81.50616  pr_hist  0.000002  2020      Q1     0.000161
# 3    44146  41.41371  -81.50582  pr_hist  0.000002  2020      Q1     0.000161
# 4    44146  41.41278  -81.50616  pr_hist  0.000003  2020      Q1     0.000161
#
#    extreme
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
quarterlyExtremes = nextPeriod[['variable','year','quarter','zipcode','extreme','latitude','longitude']].\
    groupby(['variable','year','quarter','zipcode','latitude','longitude']).sum().reset_index()

# %%
quarterlyExtremes.head()
# Out:
#   variable  year quarter  zipcode  latitude  longitude  extreme
# 0  pr_hist  2020      Q1     1226  42.47064  -73.17891        8
# 1  pr_hist  2020      Q1     1434  42.53712  -71.62612        5
# 2  pr_hist  2020      Q1     1434  42.53716  -71.62616        5
# 3  pr_hist  2020      Q1     1460  42.51834  -71.51949        5
# 4  pr_hist  2020      Q1     1473  42.55072  -71.90098        5

# %%
quarterlyExtremesMean = quarterlyExtremes[['variable','quarter','zipcode','latitude','longitude','extreme']].\
    groupby(['variable','quarter','zipcode','latitude','longitude']).mean().reset_index()

# %%
quarterlyExtremesMean.head()
# Out:
#   variable quarter  zipcode  latitude  longitude   extreme
# 0  pr_hist      Q1     1226  42.47064  -73.17891  5.428571
# 1  pr_hist      Q1     1434  42.53712  -71.62612  5.476190
# 2  pr_hist      Q1     1434  42.53716  -71.62616  5.476190
# 3  pr_hist      Q1     1460  42.51834  -71.51949  5.476190
# 4  pr_hist      Q1     1473  42.55072  -71.90098  5.476190

# %%
quarterlyExtremesMean = quarterlyExtremesMean.merge(quants[['zipcode','variable','quarter','daysExtreme']])
quarterlyExtremesMean.head()
# Out:
#   variable quarter  zipcode  latitude  longitude   extreme  daysExtreme
# 0  pr_hist      Q1     1226  42.47064  -73.17891  5.428571          4.5
# 1  pr_hist      Q1     1434  42.53712  -71.62612  5.476190          4.5
# 2  pr_hist      Q1     1434  42.53716  -71.62616  5.476190          4.5
# 3  pr_hist      Q1     1460  42.51834  -71.51949  5.476190          4.5
# 4  pr_hist      Q1     1473  42.55072  -71.90098  5.476190          4.5

# %%
quarterlyExtremesMean.to_csv("../../data/companyData/quarterlyExtremesMean.csv")

# %%
quarterlyExtremesMean.groupby(['variable']).extreme.describe()
# Out:
#                count       mean        std       min       25%       50%  \
# variable
# pr_hist      30412.0   4.708987   0.904902  2.428571  4.095238  4.571429
# tasmax_hist  30412.0  17.414102  26.551453  0.000000  0.000000  2.000000
#
#                    75%        max
# variable
# pr_hist       5.333333   7.571429
# tasmax_hist  25.619048  91.761905

# %% [markdown]
# ------------------------------

# %%
# we might have multiple records from within the same zipcode
quarterlyExtremesMean = quarterlyExtremes[['variable','quarter','zipcode','extreme']].\
    groupby(['variable','quarter','zipcode']).mean().reset_index()

# .groupby(['variable','quarter','zipcode']).mean().reset_index()

# %%
quarterlyExtremesMean.groupby('variable').extreme.hist(bins = 100)
# Out:
# variable
# pr_hist        AxesSubplot(0.125,0.125;0.775x0.755)
# tasmax_hist    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: extreme, dtype: object

# %%
(quarterlyExtremesMean[quarterlyExtremesMean.variable == 'tasmax_hist'].extreme - 4.5).hist(bins = 100)

# %%
(quarterlyExtremesMean[quarterlyExtremesMean.variable == 'pr_hist'].extreme - 4.5).hist(bins = 100)

# %%
sum(quarterlyExtremesMean[quarterlyExtremesMean.variable == 'pr_hist'].extreme > 4.5)/quarterlyExtremesMean[quarterlyExtremesMean.variable == 'pr_hist'].shape[0]
# Out:
# 0.5886075949367089

# %%
sum(quarterlyExtremesMean[quarterlyExtremesMean.variable == 'tasmax_hist'].\
    extreme > 4.5)/quarterlyExtremesMean[quarterlyExtremesMean.variable == 'tasmax_hist'].shape[0]
# Out:
# 0.9983591186122832
