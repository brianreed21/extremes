# %%
import pickle as pkl
import pandas as pd
import matplotlib
import os
import re

import collections
import datetime
import time

import geopandas as gpd

import numpy as np

import rasterio

import spacy
  
nlp = spacy.load('en_core_web_lg')
from sklearn.metrics.pairwise import cosine_similarity

import itertools

# %% [markdown]
# # Get Full IG Dataset

# %%
file = "../../data/companyData/infogroup2010s.csv"

# %%
import dask.dataframe as dd

df = dd.read_csv(file, assume_missing=True, 
                 dtype={'parent_number': 'object','parent_employee_size_code': 'object',
                       'parent_sales_volume_code': 'object',
                       'abi': 'object','zipcode': 'object'}, low_memory = False)
df = df[df.business_status_code == 1.0]
# Out:
# /Users/brianreed/opt/anaconda3/lib/python3.7/site-packages/dask/dataframe/utils.py:14: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
abiRents = df[['abi','parent_number']].drop_duplicates().compute(num_workers = 25)

# %%
abiRents.to_csv("../../data/abiRents.csv")

# %%
differentParents.to_csv("../../data/differentParents2010s.csv")

# %%
hq = df[['abi','ticker','company','archive_version_year','state','city',
         'address_line_1','zipcode',
         'latitude','longitude']].drop_duplicates().compute(num_workers = 100)

# %%
hqsOnly = hq[['abi','company']].drop_duplicates()

# %%
hqsOnly.company.value_counts()

# %%
print(hq.shape,hqsOnly.shape)

# %% [markdown]
# Some of the abi numbers seem to be duplicated; it looks like they might be primarily for different government agencies.

# %%
hqsOnly.company.value_counts()[hqsOnly.company.value_counts() > 10].index

# %%
toDiscard = hqsOnly.company.value_counts()[hqsOnly.company.value_counts() > 1].index
for company in toDiscard:
    print(company)

# %%
toDiscard

# %%
hqsOnly = hqsOnly[~hqsOnly.company.isin(toDiscard)]
hq      = hq[~hq.company.isin(toDiscard)]

# %%
hq.shape

# %% [markdown]
# At this point, we have a unique record of every company - hq here. Some of these may well be duplicate entries for a given company, for the cases in which we have a company that has multiple hq.
#
# Let's stash it so that we don't have to go through the above ^^ again.

# %%
hqsOnly.to_csv("../../data/ig2010s_uniqueHQs.csv")

# %%
hq.to_csv("../../data/ig2010s_uniqueHQs_multLocations.csv")

# %% [markdown]
# ## Grab Compustat Data
#
# First filter down to the companies for whom we have the supply chain information.

# %%
c_links = pd.read_csv("../../data/companyData/compustatSCLinked.csv")

c_links['year'] = c_links.srcdate.astype('str').str.slice(0,4).astype('int64')

c_links = c_links[c_links.year > 2009]

relevant_gvkeys = c_links.gvkey.append(c_links.cgvkey).drop_duplicates()

print(c_links.head(),relevant_gvkeys.shape)
# Out:
#      gvkey                        conm  cgvkey                       cconm  \
# 80    1013  ADC TELECOMMUNICATIONS INC    9899                    AT&T INC
# 81    1013  ADC TELECOMMUNICATIONS INC    2136  VERIZON COMMUNICATIONS INC
# 281   1094                  ACETO CORP   31673      AMERISOURCEBERGEN CORP
# 282   1094                  ACETO CORP   31673      AMERISOURCEBERGEN CORP
# 283   1094                  ACETO CORP    7171               MCKESSON CORP
#
#                        cnms   srcdate  cid  sid    ctype   salecs     scusip  \
# 80                     AT&T  20100930   16    0  COMPANY  300.000  000886309
# 81   VERIZON COMMUNICATIONS  20100930   13    0  COMPANY  146.000  000886309
# 281  AmerisourceBergen Corp  20160630   13    0  COMPANY   78.193  004446100
# 282  AmerisourceBergen Corp  20170630   13    0  COMPANY   76.598  004446100
# 283           McKesson Corp  20170630   19    0  COMPANY   70.215  004446100
#
#        stic     ccusip ctic  year
# 80   ADCT.1  00206R102    T  2010
# 81   ADCT.1  92343V104   VZ  2010
# 281   ACETQ  03073E105  ABC  2016
# 282   ACETQ  03073E105  ABC  2017
# 283   ACETQ  58155Q103  MCK  2017   (4154,)

# %%
c_links.gvkey.unique().shape[0]
# Out:
# 2479

# %% [markdown]
# Get the company dataset and check.
#
# The legal name and the given name are slightly different, but basically the same modulo punctuation and case.

# %%
c_addresses = pd.read_csv("../../data/companyData/compustatAddresses.csv", 
                dtype={'parent_number': 'object'})[['fyear',
                'gvkey',
                'conm',
                'add1',
                'city',
                'state',
                'idbflag',
                'addzip',
               'naics']].drop_duplicates().rename(columns = {'fyear': 'year'})
c_addresses = c_addresses[(c_addresses.year > 2009) & (c_addresses.year < 2020) & \
                          c_addresses.gvkey.isin(relevant_gvkeys)]
# Out:
# /Users/brianreed/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
c_addresses.year.value_counts()
# Out:
# 2012.0    3042
# 2013.0    3020
# 2011.0    3018
# 2014.0    2968
# 2010.0    2927
# 2015.0    2849
# 2016.0    2766
# 2017.0    2662
# 2018.0    2522
# 2019.0    2391
# Name: year, dtype: int64

# %% [markdown]
# We can later, potentially, subset this to focus on firms in: ag, mining, construction, manufacturing, wholesale and retail, and transportation.

# %%
'''c_addresses = c_addresses[(c_addresses.naics.astype('str').str.slice(0,2).isin(['11','21','22','23','31','32',
                                                         '33','42','44','45','48','49']))]
'''
chq = c_addresses[['gvkey','conm','add1','city','state','addzip','idbflag']].drop_duplicates()

# %% [markdown]
# We're starting with the compustat north america dataset. Not all of the HQs are in North America, so we can filter some of the information down to match with Infogroup.

# %%
chq.idbflag.value_counts()
# Out:
# D    2832
# B     752
# Name: idbflag, dtype: int64

# %%
canadian = ['ON', 'AB','QC', 'BC', 'NS', 'NF', 'SK', 'MB', 'NB']

chq.state.unique()
# Out:
# array(['MN', 'TX', 'AZ', 'UT', 'IL', 'NY', 'CA', nan, 'FL', 'CT', 'NC',
#        'WA', 'ON', 'ID', 'OH', 'GA', 'PA', 'MA', 'OK', 'VT', 'CO', 'DE',
#        'NJ', 'IN', 'MD', 'PR', 'HI', 'QC', 'WI', 'NE', 'BC', 'MO', 'VA',
#        'AB', 'RI', 'LA', 'MI', 'TN', 'DC', 'KY', 'AR', 'OR', 'AL', 'IA',
#        'KS', 'NV', 'MS', 'NH', 'SD', 'SC', 'MT', 'ME', 'NF', 'NS', 'VI',
#        'NM', 'WY', 'SK', 'ND', 'WV', 'MB'], dtype=object)

# %%
chq = chq[~(chq.state.isin(canadian)) & ~chq.state.isna()]

# %%
chq.addzip.str.len().value_counts()
# Out:
# 5     2651
# 10     329
# Name: addzip, dtype: int64

# %%
chq['addzip'] = chq.addzip.astype('str').str.slice(0,5)

# %%
chq[chq.idbflag == 'D'].addzip.str.len().value_counts()
# Out:
# 5    2589
# Name: addzip, dtype: int64

# %%
chq[chq.idbflag == "B"].addzip.value_counts()
# Out:
# 77002    12
# 10036     5
# 95054     5
# 10017     5
# 80202     5
#          ..
# 01864     1
# 78259     1
# 75243     1
# 02903     1
# 63105     1
# Name: addzip, Length: 299, dtype: int64

# %%
print(chq.head(),chq.shape)
# Out:
#     gvkey                         conm  \
# 12   1013   ADC TELECOMMUNICATIONS INC
# 13   1045  AMERICAN AIRLINES GROUP INC
# 68   1075   PINNACLE WEST CAPITAL CORP
# 79   1076            PROG HOLDINGS INC
# 91   1078          ABBOTT LABORATORIES
#
#                                       add1           city state addzip idbflag
# 12                  13625 Technology Drive   Eden Prairie    MN  55344       D
# 13                         1 Skyview Drive     Fort Worth    TX  76155       B
# 68  400 North Fifth Street, P.O. Box 53999        Phoenix    AZ  85072       D
# 79                     256 West Data Drive         Draper    UT  84020       D
# 91       100 Abbott Park Road, Abbott Park  North Chicago    IL  60064       B   (2980, 7)

# %%
chq.rename(columns = {'conm': 'company','addzip': 'cstatZipcode'},inplace = True)
chq.head()
# Out:
#     gvkey                      company  \
# 12   1013   ADC TELECOMMUNICATIONS INC
# 13   1045  AMERICAN AIRLINES GROUP INC
# 68   1075   PINNACLE WEST CAPITAL CORP
# 79   1076            PROG HOLDINGS INC
# 91   1078          ABBOTT LABORATORIES
#
#                                       add1           city state cstatZipcode  \
# 12                  13625 Technology Drive   Eden Prairie    MN        55344
# 13                         1 Skyview Drive     Fort Worth    TX        76155
# 68  400 North Fifth Street, P.O. Box 53999        Phoenix    AZ        85072
# 79                     256 West Data Drive         Draper    UT        84020
# 91       100 Abbott Park Road, Abbott Park  North Chicago    IL        60064
#
#    idbflag
# 12       D
# 13       B
# 68       D
# 79       D
# 91       B

# %%
chq = chq[chq.gvkey.isin(relevant_gvkeys)]

# %%
chq.shape
# Out:
# (2980, 7)

# %%
chq.to_csv("../../data/chq.csv")

# %% [markdown]
# # Breakpoint
# We can start from here and just clean everything from here.
#
#
# Headquarters:

# %%
chq     = pd.read_csv("../../data/chq.csv",dtype={'cstatZipcode': 'object'}).drop(columns = {'Unnamed: 0'})

chq.head()
# Out:
#    gvkey                      company                                    add1  \
# 0   1013   ADC TELECOMMUNICATIONS INC                  13625 Technology Drive
# 1   1045  AMERICAN AIRLINES GROUP INC                         1 Skyview Drive
# 2   1075   PINNACLE WEST CAPITAL CORP  400 North Fifth Street, P.O. Box 53999
# 3   1078          ABBOTT LABORATORIES       100 Abbott Park Road, Abbott Park
# 4   1094                   ACETO CORP                      4 Tri Harbor Court
#
#               city state cstatZipcode idbflag
# 0     Eden Prairie    MN        55344       D
# 1       Fort Worth    TX        76155       B
# 2          Phoenix    AZ        85072       D
# 3    North Chicago    IL        60064       B
# 4  Port Washington    NY        11050       D

# %%
hqsOnly     = pd.read_csv("../../data/ig2010s_uniqueHQs.csv").drop(columns = {'Unnamed: 0'})
hqsWithYear = pd.read_csv("../../data/ig2010s_uniqueHQs_multLocations.csv",dtype={'zipcode': 'object'})[['abi','company',
                                                                             'archive_version_year',
                                                                             'state','city','zipcode','address_line_1']]

print(hqsOnly.head())
print(hqsWithYear.head())

hqsWithYear = hqsWithYear[hqsWithYear.archive_version_year <= 2020]

hqsWithYear['last_year'] = hqsWithYear.groupby(['abi'])['archive_version_year'].transform(max)

print(hqsWithYear.shape)

lastHQs = hqsWithYear[hqsWithYear.archive_version_year == hqsWithYear.last_year][['abi','company','state','city','zipcode','address_line_1']]

print(lastHQs.shape)

lastHQs.head()
# Out:
#      abi                         company
# 0   7609            SOLITRON DEVICES INC
# 1  21311   WESTERN STATES ENVELOPE & LBL
# 2  29603                THIELE KAOLIN CO
# 3  71340                 TRI STAFF GROUP
# 4  77743  NATIONAL TECHNICAL SYSTEMS INC
#      abi                         company  archive_version_year state  \
# 0   7609            SOLITRON DEVICES INC                2010.0    FL
# 1  21311   WESTERN STATES ENVELOPE & LBL                2010.0    WI
# 2  29603                THIELE KAOLIN CO                2010.0    GA
# 3  71340                 TRI STAFF GROUP                2010.0    CA
# 4  77743  NATIONAL TECHNICAL SYSTEMS INC                2010.0    CA
#
#               city zipcode            address_line_1
# 0  WEST PALM BEACH   33407  3301 ELECTRONICS WAY # C
# 1           BUTLER   53007           4480 N 132ND ST
# 2     SANDERSVILLE   31082             520 KAOLIN RD
# 3        SAN DIEGO   92122   6336 GREENWICH DR # 100
# 4        CALABASAS   91302  24007 VENTURA BLVD # 200
# (394920, 8)
# (59805, 6)
#        abi                     company state             city zipcode  \
# 17  158329            CARIDIAN BCT INC    CO         LAKEWOOD   80401
# 20  211946      FAMILY BRANDS INTL LLC    TN      LENOIR CITY   37771
# 23  258574                   JADE CORP    PA   HUNTINGDON VLY   19006
# 24  262493  MONTANA METAL PRODUCTS LLC    IL      DES PLAINES   60018
# 43  455154                    O I CORP    TX  COLLEGE STATION   77845
#
#                   address_line_1
# 17  14143 DENVER WEST PKWY # 200
# 20              1001 ELM HILL RD
# 23             3063 PHILMONT AVE
# 24                 25 HOWARD AVE
# 43                 151 GRAHAM RD

# %%
lastHQs.to_csv("../../data/companyData/lastHQs.csv")

# %% [markdown]
# Only two of these company names appear 2x, which is good. There are ~20,000 companies in this sample.
#
# Let's go through a little bit of a process here:
# - Find the exact matches.
# - Get a similarity measure between ; ideally something vectorized / something in matrix math.
# - Find the top 10 matches for the remaining ones.
# - Do some mix and match and see if there's any threshold at which matches become similar ``enough'' to say this is okay and good to go.
#
#
# We might be able to use the fact that all of the addresses should be the same after some given point, as the compustat addresses are only the most recent ones.

# %% [markdown]
# Let's try a few different ways to match these up.
#
# First, let's find the exact matches.

# %% [markdown]
# Make a generic cleaning function that strips out all company names, any punctuation in the name, and makes everything lower case.

# %%
def cleanText(text):
    text = text.strip().\
    sub(" CORP","").replace(" CO","").replace(" INC","").\
    replace(" LTD","").replace(" -CL A","").\
    replace(" -LP","").replace(" LP","").\
    replace("-OLD","").replace(" LLC","").\
    replace(", LLC.","").replace(" L.L.C.","").replace(" L.P.","").\
    replace(" L.TD","").replace(" L.L.C.","").replace(" -CL B","").\
    replace(" -CL B","").replace(" -CL i","").replace(" -CL","").\
    replace("-REDH","").replace(" CP","").\
    replace("-ADR","").replace(" PLC","").lower().replace(r'[^\w\s]+', '').\
    replace('-lp','').replace('-spn','').replace('hldg','').replace(' intl','').\
    replace('holdings','').replace('holding','').replace('prtnr','').replace('group','').\
    replace(" med ", " medical ").replace(" tradng ", " trading ").replace("gen ", "general ").\
    replace(" mtr ", " motors ").replace(" motor ", " motors ").replace("-", " ").\
    replace("/", " ").replace("'", " ").replace("&", " ").replace(" a g ", " ").\
    replace(" ag ", " ").replace("  adr ", " ").replace(" adr ", " ").replace("  cp ", " ").\
    replace(" cp ", " ").replace(" plc ", " ").replace(" intl ", " ").replace(" ent ", " ").\
    replace(" nv ", " ").replace(" n.v. ", " ").replace(" worldwide ", " ").\
    replace(" wldwide ", " ").replace(" banc"," bank").replace("^banc","bank")
    
    return text

# %%
chq['company']               = list(map(cleanText, chq.company))
lastHQs['company']           = list(map(cleanText, lastHQs.company))

chq.rename(columns = {'city': 'cstatCity',
                     'state': 'cstatState',
                     'add1': 'cstatadd1'}, inplace = True)

chq['cstatCity']  = chq.cstatCity.str.lower()
chq['cstatState'] = chq.cstatState.str.lower()
chq['cstatadd1']  = chq.cstatadd1.str.lower()

lastHQs['city']            = lastHQs.city.str.lower()
lastHQs['state']           = lastHQs.state.str.lower()
lastHQs['address_line_1']  = lastHQs.address_line_1.str.lower()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-78d88b199a6b> in <module>
# ----> 1 chq['company']               = list(map(cleanText, chq.company))
#       2 lastHQs['company']           = list(map(cleanText, lastHQs.company))
#       3
#       4 chq.rename(columns = {'city': 'cstatCity',
#       5                      'state': 'cstatState',
#
# NameError: name 'chq' is not defined

# %% [markdown]
# NAICS names do not match up between compustat and infogroup so they're not helpful.

# %%
chq.head()
# Out:
#     gvkey                 company                               cstatadd1  \
# 12   1013  adc telecommunications                  13625 technology drive
# 13   1045      american airlines                          1 skyview drive
# 68   1075   pinnacle west capital  400 north fifth street, p.o. box 53999
# 79   1076                   prog                      256 west data drive
# 91   1078     abbott laboratories       100 abbott park road, abbott park
#
#         cstatCity cstatState cstatZipcode idbflag
# 12   eden prairie         mn        55344       D
# 13     fort worth         tx        76155       B
# 68        phoenix         az        85072       D
# 79         draper         ut        84020       D
# 91  north chicago         il        60064       B

# %%
lastHQs.head()
# Out:
#        abi                 company state             city zipcode  \
# 17  158329            caridian bct    co         lakewood   80401
# 20  211946           family brands    tn      lenoir city   37771
# 23  258574                    jade    pa   huntingdon vly   19006
# 24  262493  montana metal products    il      des plaines   60018
# 43  455154                     o i    tx  college station   77845
#
#                   address_line_1
# 17  14143 denver west pkwy # 200
# 20              1001 elm hill rd
# 23             3063 philmont ave
# 24                 25 howard ave
# 43                 151 graham rd

# %% [markdown]
# ## Match on company name directly

# %%
nameMerge = chq.merge(lastHQs)
nameMerge.shape
# Out:
# (2243, 12)

# %%
nameMerge.head()
# Out:
#    gvkey                 company                               cstatadd1  \
# 0   1013  adc telecommunications                  13625 technology drive
# 1   1045      american airlines                          1 skyview drive
# 2   1075   pinnacle west capital  400 north fifth street, p.o. box 53999
# 3   1078     abbott laboratories       100 abbott park road, abbott park
# 4   1094                   aceto                      4 tri harbor court
#
#          cstatCity cstatState cstatZipcode idbflag        abi state  \
# 0     eden prairie         mn        55344       D    7523129    mn
# 1       fort worth         tx        76155       B    7501711    tx
# 2          phoenix         az        85072       D    4554051    az
# 3    north chicago         il        60064       B    4352373    il
# 4  port washington         ny        11050       D  433140944    tx
#
#            city zipcode           address_line_1
# 0  eden prairie   55344      13625 technology dr
# 1    fort worth   76155             1 skyview dr
# 2       phoenix   85004        400 n 5th st frnt
# 3   abbott park   60064       100 abbott park rd
# 4       houston   77010  1221 mckinney st # 3275

# %%
nameMerge.to_csv("../../data/companyData/nameMerge.csv")

# %%
sum(nameMerge.cstatState == nameMerge.state)/nameMerge.shape[0]
# Out:
# 0.9549710209540794

# %%
sum(nameMerge.cstatZipcode.str.slice(0,5) == nameMerge.zipcode.str.slice(0,5))/nameMerge.shape[0]
# Out:
# 0.8818546589389211

# %%
sum(nameMerge.cstatZipcode.str.slice(0,1) == nameMerge.zipcode.str.slice(0,1))/nameMerge.shape[0]
# Out:
# 0.9621043245653144

# %%
nameMerge[nameMerge.cstatCity != nameMerge.city][50:100]
# Out:
#      gvkey                  company  \
# 438   9922                  sparton
# 442  10115                  stryker
# 444  10156                   sunoco
# 445  12892                   sunoco
# 450  10195      superior industries
# 485  10860                   ameren
# 488  10884          chiquita brands
# 490  10903            unitedhealth
# 494  10984                   sprint
# 496  11060                       vf
# 500  11169            video display
# 503  11228         vulcan materials
# 529  11910                   novell
# 534  12081           gladstone land
# 539  12142                   oracle
# 553  12338  health management assoc
# 556  12392                  skywest
# 557  12395            toll brothers
# 562  12482               clearfield
# 565  12544                   st joe
# 583  12850                   cerner
# 593  13125    healthpeak properties
# 604  13431                    berry
# 611  13634       exide technologies
# 616  13782              multi color
# 620  13824               fair isaac
# 642  14417              micronetics
# 666  15274            walter energy
# 668  15459                 tredegar
# 672  15708                 allergan
# 714  17931  portola pharmaceuticals
# 716  17941   qep midstream partners
# 723  18109             jones energy
# 727  18179    world point terminals
# 729  18235           saexploration
# 733  18320             fox factory
# 735  18430  five prime therapeutics
# 742  18561             benefitfocus
# 748  18623            violin memory
# 760  18805                  gdt tek
# 770  18947                 veracyte
# 786  19439                 kaiser
# 793  19574                  gannett
# 796  19602             turtle beach
# 797  19747      quotient technology
# 816  20088                      box
# 827  20280            new york reit
# 836  20537       jp energy partners
# 841  20672           adeptus health
# 865  21431     california resources
#
#                                              cstatadd1            cstatCity  \
# 438                             5612 johnson lake road      de leon springs
# 442                             2825 airview boulevard            kalamazoo
# 444                       1735 market street, suite ll         philadelphia
# 445                  8111 westchester drive, suite 400               dallas
# 450                    26600 telegraph road, suite 400           southfield
# 485                               1901 chouteau avenue          saint louis
# 488                          550 south caldwell street            charlotte
# 490     unitedhealth group center, 9900 bren road east           minnetonka
# 494                                6200 sprint parkway        overland park
# 496                                1551 wewatta street               denver
# 500                                   5155 king street                cocoa
# 503                            1200 urban center drive           birmingham
# 529                            1800 south novell place                provo
# 534                   1521 westbranch drive, suite 100               mclean
# 539                                    2300 oracle way               austin
# 553              5811 pelican bay boulevard, suite 500               naples
# 556                               444 south river road         saint george
# 557                                1140 virginia drive      fort washington
# 562  7050 winnetka avenue north, suite 100, brookly...          minneapolis
# 565           130 richard jackson boulevard, suite 200    panama city beach
# 583                             2800 rockcreek parkway    north kansas city
# 593              5050 south syracuse street, suite 800               denver
# 604              16000 north dallas parkway, suite 500               dallas
# 611              13000 deerfield parkway, building 200               milton
# 616                   4053 clough woods drive, batavia           cincinnati
# 620                       5 west mendenhall, suite 105              bozeman
# 642                                 201 riverneck road           chelmsford
# 666               3000 riverchase galleria, suite 1700           birmingham
# 668                              1100 boulders parkway             richmond
# 672                                  2525 dupont drive               irvine
# 714                              270 east grand avenue  south san francisco
# 716                            19100 ridgewood parkway          san antonio
# 723                   807 las cimas parkway, suite 350               austin
# 727                  8235 forsyth boulevard, suite 400            st. louis
# 729                           13645 n. promenade blvd.             stafford
# 733                   2055 sugarloaf circle, suite 300               duluth
# 735                         111 oyster point boulevard  south san francisco
# 742                               100 benefitfocus way           charleston
# 748                           2375 telstar drive, #150     colorado springs
# 760             3001 north rocky point road, suite 200                tampa
# 770                    6000 shoreline court, suite 300  south san francisco
# 786                             1943 50th street north           birmingham
# 793                            7950 jones branch drive               mclean
# 796                       44 south broadway, 4th floor         white plains
# 797              1260 east stringham avenue, suite 600       salt lake city
# 816                               900 jefferson avenue         redwood city
# 827                        7 bulfinch place, suite 500               boston
# 836    building #4, suite 800, 2103 citywest boulevard              houston
# 841                    206 east 9th street, suite 1300               austin
# 865                      27200 tourney road, suite 200        santa clarita
#
#     cstatState cstatZipcode idbflag        abi state             city zipcode  \
# 438         fl        32130       D    8383333    il       schaumburg   60173
# 442         mi        49002       B  143964906    mi          portage   49002
# 444         pa        19103       D  464706795    tx           dallas   75225
# 445         tx        75225       D    4556221    pa     philadelphia   19103
# 450         mi        48033       D  413582201    mn           morris   56267
# 485         mo        63103       B  967282336    mo         st louis   63103
# 488         nc        28202       D  200053361    fl      dania beach   33004
# 490         mn        55343       B    4373189    mn          hopkins   55343
# 494         ks        66251       B  400038995    tx         richmond   77469
# 496         co        80202       D    7538861    co    greenwood vlg   80111
# 500         fl        32926       D  424244671    ga           tucker   30084
# 503         al        35242       D    7539398    al         vestavia   35242
# 529         ut        84606       D    3542222    ma          waltham   02451
# 534         va        22102       B  425956338    va          mc lean   22102
# 539         tx        78741       B  452146293    ca     redwood city   94065
# 553         fl        34108       D  311476683    mi          lansing   48933
# 556         ut        84790       D    4716585    ut        st george   84790
# 557         pa        19034       D  121181911    pa          horsham   19044
# 562         mn        55428       D  501829584    mn    brooklyn park   55428
# 565         fl        32407       D    7534910    fl       watersound   32461
# 583         mo        64117       D  154146161    mo      kansas city   64117
# 593         co        80237       D  503996811    ca           irvine   92614
# 604         tx        75248       D  425673043    ks          wichita   67219
# 611         ga        30004       D  400648903    ga       alpharetta   30004
# 616         oh        45103       D    9277914    oh          batavia   45103
# 620         mt        59715       B  103048286    ca         san jose   95110
# 642         ma        01824       D    4254223    nh           hudson   03051
# 666         al        35244       D  441471463    al           hoover   35244
# 668         va        23225       D  200105807    va   n chesterfield   23225
# 672         ca        92612       D  172439986    nj          madison   07940
# 714         ca        94080       D  251607412    ca  s san francisco   94080
# 716         tx        78259       D  433215957    co           denver   80265
# 723         tx        78746       D  488511288    tx  west lake hills   78746
# 727         mo        63105       D  433202616    mo         st louis   63105
# 729         tx        77477       D  700213320    tx          houston   77079
# 733         ga        30097       D  417495205    ga        braselton   30517
# 735         ca        94080       D  625087002    ca  s san francisco   94080
# 742         sc        29492       D  654433515    sc    daniel island   29492
# 748         co        80920       D  405113577    ca      santa clara   95054
# 760         fl        33771       D  506481233    fl          orlando   32803
# 770         ca        94080       D  405884243    ca  s san francisco   94080
# 786         al        35212       D  592301881    va          fairfax   22031
# 793         va        22107       D  816332985    de            dover   19904
# 796         ny        10601       D  403319780    ca        san diego   92127
# 797         ut        84106       D  351928544    ca    mountain view   94043
# 816         ca        94063       D  220309405    tx         stafford   77477
# 827         ma        02114       D  435380234    ny         new york   10022
# 836         tx        77042       D  421114234    tx           irving   75039
# 841         tx        78701       D  436245464    tx       lewisville   75067
# 865         ca        91355       D  421979337    ca         valencia   91355
#
#                      address_line_1
# 438      425 n martingale rd # 1000
# 442               2825 airview blvd
# 444       8111 westchester dr # 600
# 445           1818 market st # 1500
# 450            315 state highway 28
# 485               1901 chouteau ave
# 488          1855 griffin rd # c436
# 490           9900 bren rd e # 300w
# 494                 2141 preston st
# 496               8505 e orchard rd
# 500       1868 tucker industrial rd
# 503            1200 urban center dr
# 529             404 wyman st # 500a
# 534          1521 westbranch dr # 2
# 539                 500 oracle pkwy
# 553       120 n washington sq # 705
# 556                  444 s river rd
# 557                250 gibraltar rd
# 562       7050 winnetka ave n # 100
# 565           133 s watersound pkwy
# 583            2800 rock creek pkwy
# 593             1920 main st # 1200
# 604                2402 e 37th st n
# 611      13000 deerfield pkwy # 200
# 616            4053 clough woods dr
# 620              181 metro dr # 700
# 642                 26 hampshire dr
# 666  3000 riverchase galleria #1700
# 668        1100 boulders pkwy # 200
# 672                 5 giralda farms
# 714            270 e grand ave # 22
# 716              1050 17th st # 500
# 723        807 las cimas pkwy # 350
# 727         8235 forsyth blvd # 400
# 729     1160 dairy ashford rd # 160
# 733                 6634 highway 53
# 735           111 oyster point blvd
# 742            100 benefitfocus way
# 748   4555 great america pkwy # 150
# 760              2816 e robinson st
# 770         6000 shoreline ct # 300
# 786                    9300 lee hwy
# 793      820 silver lake blvd # 100
# 796          11011 via frontera # a
# 797                   400 logue ave
# 816        10125 stafford centre dr
# 827                    405 park ave
# 836   600 las colinas blvd e # 2000
# 841        2941 lake vista dr # 200
# 865          27200 tourney rd # 200

# %% [markdown]
# Now focus down onto the companies that have not been matched.

# %%
chqUnmatched = chq[~chq.company.isin(nameMerge.company)].reset_index()
chqUnmatched.shape
# Out:
# (769, 8)

# %%
igUnmatched  = lastHQs[~lastHQs.company.isin(nameMerge.company)].reset_index()
igUnmatched.shape
# Out:
# (57570, 7)

# %%
lastHQs.shape
# Out:
# (59805, 6)

# %% [markdown]
# # Find Distance

# %% [markdown]
# Two distance measures here. Look at top 5 matches and pull the distance measure and matches as well.
#
# ### Levenshtein

# %%
from Levenshtein import distance as levenshtein_distance

# %% [markdown]
# Find LD between the unmatched compustat companies and the unmatched IG ones.

# %%
companyArrayCStat = []

company = chqUnmatched.company[0]
start = time.time()
for company in chqUnmatched.company:
    thisCompany = []
    for ig in igUnmatched.company:
        thisCompany.append(levenshtein_distance(company,ig))
    
    companyArrayCStat.append([thisCompany])

allLD = np.concatenate(companyArrayCStat)

# %%
igUnmatched.head()
# Out:
#    index     abi                 company state             city zipcode  \
# 0     17  158329            caridian bct    co         lakewood   80401
# 1     20  211946           family brands    tn      lenoir city   37771
# 2     23  258574                    jade    pa   huntingdon vly   19006
# 3     24  262493  montana metal products    il      des plaines   60018
# 4     43  455154                     o i    tx  college station   77845
#
#                  address_line_1
# 0  14143 denver west pkwy # 200
# 1              1001 elm hill rd
# 2             3063 philmont ave
# 3                 25 howard ave
# 4                 151 graham rd

# %% [markdown]
# Now pull the closest companies in IG to those in CStat. We'll first populate a dataframe with the name, address, city, state, and zip of each unmatched company in compustat, then we'll use the LD to find the same information for the closest company in IG.
#
#
#
# There's some legacy code in here that finds the top 5 closest companies; but it doesn't populate the dataframe.

# %%
singleLargestLV   = (allLD).argsort(axis=-1)[:, :1]

# legacy
# n = 5
# largestElementsLV = (allLD).argsort(axis=-1)[:, :n]


companyMatches = pd.DataFrame()
companyMatches['cstatCompanies'] = chqUnmatched.company
companyMatches['cstatadd1']      = chqUnmatched.cstatadd1
companyMatches['cstatCity']      = chqUnmatched.cstatCity
companyMatches['cstatState']     = chqUnmatched.cstatState
companyMatches['cstatZip']       = chqUnmatched.cstatZipcode

for i in range(0,companyMatches.shape[0]):
    # print(list(np.array(hq.company)[largestElements[i]]))
    companyMatches.at[i,'misspelling']         = allLD[i,:][singleLargestLV[i]]
    companyMatches.at[i,'percMisspelled']      = companyMatches.misspelling[i]/len(companyMatches.cstatCompanies[i])
    companyMatches.at[i,'levCompany']          = igUnmatched.company[singleLargestLV[i]].iloc[0]
    
    companyMatches.at[i,'closestMatchIG_add']      = igUnmatched.address_line_1[singleLargestLV[i]].iloc[0]
    companyMatches.at[i,'closestMatchIG_city']     = igUnmatched.city[singleLargestLV[i]].iloc[0]
    companyMatches.at[i,'closestMatchIG_zipcode']  = igUnmatched.zipcode[singleLargestLV[i]].iloc[0]
    companyMatches.at[i,'closestMatchIG_state']    = igUnmatched.state[singleLargestLV[i]].iloc[0]

    
    # companyMatches.at[i,'closestMatchIG']      = np.array(igUnmatched.company)[largestElementsLV[i]]
    # companyMatches.at[i,'LevSim']              = np.array(allLD[i,:][largestElementsLV[i]], dtype=object)

# %%
companyMatches.head()
# Out:
#         cstatCompanies                           cstatadd1  cstatCity  \
# 0                prog                  256 west data drive     draper
# 1                 beam     222 west merchandise mart plaza    chicago
# 2  american greetings                    one american road  cleveland
# 3   american software      470 east paces ferry road, n.e.    atlanta
# 4                  apa  2000 post oak boulevard, suite 100    houston
#
#   cstatState cstatZip  misspelling  percMisspelled          levCompany  \
# 0         ut    84020          1.0        0.200000                prg
# 1         il    60654          1.0        0.250000                team
# 2         oh    44144          1.0        0.052632  american greetings
# 3         ga    30305          1.0        0.055556   american software
# 4         tx    77056          1.0        0.333333                 spa
#
#              closestMatchIG_add closestMatchIG_city closestMatchIG_zipcode  \
# 0      856 us highway 206 # b12        hillsborough                  08844
# 1  13131 dairy ashford rd # 600          sugar land                  77478
# 2                1 american way            westlake                  44145
# 3       470 e paces ferry rd ne             atlanta                  30305
# 4                  2701 park dr           cleveland                  44120
#
#   closestMatchIG_state
# 0                   nj
# 1                   tx
# 2                   oh
# 3                   ga
# 4                   oh

# %% [markdown]
# Now get the embeddings and the cosine similarity between them.

# %%
def getMatrix(companyEmbeddings):
    companyArray = []
    
    for companies in companyEmbeddings:
        companyArray.append([companies.vector])
    
    companyArray = np.concatenate(companyArray)
    
    return(companyArray)

# %%
chqUnmatchedList = list(map(nlp, chqUnmatched.company))
allCompaniesIG   = list(map(nlp, igUnmatched.company))


cstat = getMatrix(chqUnmatchedList)
ig    = getMatrix(allCompaniesIG)

allSimilarities = cosine_similarity(cstat,ig)

allSimilarities.shape
# Out:
# (769, 57570)

# %%
outfile =  '../../data/allCompaniesIG_embeddings.pkl'
with open(outfile, 'wb') as pickle_file:
    pkl.dump(ig, pickle_file)
    
outfile =  '../../data/allCompaniesCStat_embeddings.pkl'
with open(outfile, 'wb') as pickle_file:
    pkl.dump(cstat, pickle_file)

# %% [markdown]
# Each row n here has the similarity between the nth company name in compustat and the IG company corresp to that column.

# %%
allSimilarities[0:5,:]
# Out:
# array([[ 0.01691091, -0.01222062,  0.06702404, ...,  0.10824974,
#          0.08654009,  0.1449641 ],
#        [-0.02306337,  0.06756251,  0.13372983, ...,  0.29612526,
#          0.07285859,  0.17976503],
#        [ 0.04563743,  0.33906224,  0.24495935, ...,  0.3366109 ,
#          0.37406623,  0.39949286],
#        [-0.0358867 ,  0.3554296 ,  0.18157756, ...,  0.43370304,
#          0.36172885,  0.3919765 ],
#        [ 0.12749049,  0.01153258,  0.11958653, ...,  0.08740962,
#          0.21394141,  0.13486943]], dtype=float32)

# %% [markdown]
# Find indices of companies in IG most similar to each company in CStat.

# %%
singleLargestCos   = (-allSimilarities).argsort(axis=-1)[:, :1]

# legacy - largest n
# largestElementsCos = (-allSimilarities).argsort(axis=-1)[:, :n]

# %% [markdown]
# Add the cosine similarity measures to the similarity dataset.

# %%
for i in range(0,companyMatches.shape[0]):
    # print(list(np.array(hq.company)[largestElements[i]]))
    companyMatches.at[i,'cosSimilarity']        = allSimilarities[i,:][singleLargestCos[i]]
    companyMatches.at[i,'cosSimilarityCompany'] = igUnmatched.company[singleLargestCos[i]].iloc[0]
    # companyMatches.at[i,'closestMatchCosine']   = np.array(igUnmatched.company)[largestElementsCos[i]]
    # companyMatches.at[i,'cosineSim']            = np.array(allSimilarities[i,:][largestElementsCos[i]], dtype=object)
    
    
    companyMatches.at[i,'costMatchIG_add']     = igUnmatched.address_line_1[singleLargestCos[i]].iloc[0]
    companyMatches.at[i,'cosMatchIG_city']     = igUnmatched.city[singleLargestCos[i]].iloc[0]
    companyMatches.at[i,'cosMatchIG_zipcode']  = igUnmatched.zipcode[singleLargestCos[i]].iloc[0]
    companyMatches.at[i,'cosMatchIG_state']    = igUnmatched.state[singleLargestCos[i]].iloc[0]

# %%
sum((companyMatches.levCompany == companyMatches.cosSimilarityCompany))
# Out:
# 171

# %% [markdown]
# ## Start Matching
#
# ### Take 1: Match + Zip or City

# %% [markdown]
# Now find the company matches: ABI - gvkey link.
#
# Start with ones where the names both match.
#
# If the cities or zipcodes match on one of the closest companies (LD or cos), it seems like it is good to go.
#
#
# Do this in steps to start, at least. First find the companies where both match and either zip or city match. Then find companies where only one matches.

# %%
bothMatch_cityZip = companyMatches[(companyMatches.levCompany == companyMatches.cosSimilarityCompany) & \
              ((companyMatches.cstatCity == companyMatches.closestMatchIG_city) | \
              (companyMatches.cstatZip == companyMatches.closestMatchIG_zipcode))]
bothMatch_cityZip.shape

bothMatch_cityZip.to_csv("../../data/companyData/bothMatch_cityZip.csv")

# %%
bothMatch_cityZip['igCompanies'] = bothMatch_cityZip.levCompany
companiesToCheck                 = bothMatch_cityZip[['cstatCompanies','igCompanies',
                                    'cstatadd1','cstatCity','cstatZip',
                                    'closestMatchIG_add','closestMatchIG_city','closestMatchIG_zipcode']]
# Out:
# /Users/brianreed/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
companyMatchesBoth = list(bothMatch_cityZip.cstatCompanies.unique())
len(companyMatchesBoth)
# Out:
# 138

# %% [markdown]
# Grab the single company match versions.

# %%
oneMatch_cityZipOnly = companyMatches[-(companyMatches.cstatCompanies.isin(companyMatchesBoth)) & \
              (((companyMatches.cstatCity == companyMatches.closestMatchIG_city) | \
              (companyMatches.cstatZip == companyMatches.closestMatchIG_zipcode)) | \
              ((companyMatches.cstatCity == companyMatches.cosMatchIG_city) | \
              (companyMatches.cstatZip == companyMatches.cosMatchIG_zipcode)))].reset_index(drop=True)

oneMatch_cityZipOnly['igCompanies'] = ''

for i in range(0,oneMatch_cityZipOnly.shape[0]):
    if ((oneMatch_cityZipOnly.cstatCity[i] == oneMatch_cityZipOnly.closestMatchIG_city[i]) | \
              (oneMatch_cityZipOnly.cstatZip[i] == oneMatch_cityZipOnly.closestMatchIG_zipcode[i])):
        oneMatch_cityZipOnly.loc[i,'igCompanies'] = oneMatch_cityZipOnly.levCompany[i]
    else:
        oneMatch_cityZipOnly.loc[i,'igCompanies'] = oneMatch_cityZipOnly.cosSimilarityCompany[i]

# oneMatch_cityZipOnly.to_csv("../../data/companyData/oneMatch_cityZipOnly.csv")

# %%
companiesToCheck.shape
# Out:
# (138, 8)

# %%
oneMatch_cityZipOnly.head()
# Out:
#                    cstatCompanies                        cstatadd1  \
# 0                            beam  222 west merchandise mart plaza
# 1  advanced oxygeneral technology     653 vt route 12a, po box 189
# 2                    southern gas        ten peachtree place, n.e.
# 3                  brt apartments   60 cutter mill road, suite 303
# 4                     barry (r g)         13405 yarmouth road n.w.
#
#       cstatCity cstatState cstatZip  misspelling  percMisspelled  \
# 0       chicago         il    60654          1.0        0.250000
# 1      randolph         vt    05060          6.0        0.200000
# 2       atlanta         ga    30309          2.0        0.166667
# 3    great neck         ny    11021          6.0        0.428571
# 4  pickerington         oh    43147          6.0        0.545455
#
#                  levCompany            closestMatchIG_add closestMatchIG_city  \
# 0                      team  13131 dairy ashford rd # 600          sugar land
# 1  advanced oxygeneral tech              653 vt route 12a            randolph
# 2              southern its       9101 w sahara ave # 105           las vegas
# 3              pjt partners            280 park ave # 15w            new york
# 4                berryllege      2277 martha berry hwy nw            mt berry
#
#   closestMatchIG_zipcode closestMatchIG_state  cosSimilarity  \
# 0                  77478                   tx       1.000000
# 1                  05060                   vt       1.000000
# 2                  89117                   nv       0.921520
# 3                  10017                   ny       0.624561
# 4                  30149                   ga       0.835597
#
#   cosSimilarityCompany                 costMatchIG_add cosMatchIG_city  \
# 0         beam suntory  222 merchandise mart plz #1600         chicago
# 1  advanced technology                   101 parker dr         andover
# 2            gas south  3625 cumberland blvd se # 1500         atlanta
# 3     brt realty trust          60 cuttermill rd # 303      great neck
# 4            r g barry               13405 yarmouth dr    pickerington
#
#   cosMatchIG_zipcode cosMatchIG_state               igCompanies
# 0              60654               il              beam suntory
# 1              44003               oh  advanced oxygeneral tech
# 2              30339               ga                 gas south
# 3              11021               ny          brt realty trust
# 4              43147               oh                 r g barry

# %%
companiesToCheck = companiesToCheck.append(oneMatch_cityZipOnly[['cstatCompanies','igCompanies',
                                    'cstatadd1','cstatCity','cstatZip',
                                    'closestMatchIG_add','closestMatchIG_city','closestMatchIG_zipcode']]).\
                                    drop_duplicates()

companiesToCheck.shape
# Out:
# (372, 8)

# %%
companiesToCheck[0:50]
# Out:
#                    cstatCompanies                     igCompanies  \
# 3              american software                american software
# 5                apco oil and gas                  apco oil   gas
# 9        constellation energy grp           constellation energy
# 23            central natural res       central natural resources
# 32   cracker barrel old ctry stor     cracker barrel olduntry str
# 37       dun   bradstreet holdngs                dun   bradstreet
# 39        electro scientific inds   electro scientific industries
# 42                 federal mogul                    federal mogul
# 43   federal national mortga assn  federal national mortgage assn
# 46           forest laboratories              forest laboratories
# 69         kimball international            kimball international
# 70                  snyders lance                  snyder s lance
# 71        jefferies financial grp            jefferies financial
# 74                        lowe ss                          lowe s
# 90                          nike                             nike
# 92      north european oil rty tr      north european oil royalty
# 94        northwest natural hldng              northwest natural
# 98                oil dri america              oil dri of america
# 99              p   f industries                 p   f industries
# 100           pnc financial svcs               pnc financial svc
# 109             pier 1 imports de                  pier 1 imports
# 110  professional diversity netwk    professional diversity ntwrk
# 111      public service entrp grp                 public service
# 117                  schlumberger                   schlumberger
# 118           scott s liquid gold         scott s liquid gold inc
# 120         shenandoah telecommun   shenandoah telecommunications
# 122            john d oil and gas                john d oil   gas
# 129      span america medical sys    span america medical systems
# 131         standard motors prods        standard motors products
# 142                  tyson foods                      tyson foods
# 147  universal security instrumnt        universal security instr
# 150       weingarten realty invst     weingarten realty investors
# 160  natural grocers vitamin ctge      natural grocers by vitamin
# 174     public service elec   gas                 public service
# 176     harman international inds        harman international ind
# 180       nationwide health pptys    nationwide health properties
# 182         blue dolphin energy               blue dolphin energy
# 202          laboratory of amer s                laboratory amer
# 219           blackhawk network s              blackhawk network
# 225          physicians realty tr         physicians realty trust
# 229        marrone bio innovtions         marrone bio innovations
# 236              container store                  container store
# 237        empire state realty op       empire state realty trust
# 243    continental building prods       continental building prod
# 244       installed bldg products         installed building prod
# 257    american realty cap hlthcr  american realty capital hlthcr
# 269            plymouth indl reit        plymouth industrial reit
# 272           medicis pharmaceut           medicis pharmaceutical
# 275                  yuma energy                      yuma energy
# 281               floor   decor s                  floor   decor
#
#                                     cstatadd1          cstatCity cstatZip  \
# 3             470 east paces ferry road, n.e.            atlanta    30305
# 5             one williams center, 35th floor              tulsa    74172
# 9                       100 constellation way          baltimore    21202
# 23                1044 main street, suite 502        kansas city    64105
# 32                         305 hartmann drive            lebanon    37087
# 37                            101 jfk parkway        short hills    07078
# 39                13900 nw science park drive           portland    97229
# 42                    27300 west 11 mile road         southfield    48034
# 43       midtown center, 1100 15th street, nw         washington    20005
# 46                           909 third avenue           new york    10022
# 69                          1600 royal street             jasper    47546
# 70           13515 ballantyne corporate place          charlotte    28277
# 71                         520 madison avenue           new york    10022
# 74                      1000 lowe's boulevard        mooresville    28117
# 90                         one bowerman drive          beaverton    97005
# 92                     5 north lincoln street              keene    03431
# 94                     250 s.w. taylor street           portland    97204
# 98       410 north michigan avenue, suite 400            chicago    60611
# 99            445 broadhollow road, suite 100           melville    11747
# 100  the tower at pnc plaza, 300 fifth avenue         pittsburgh    15222
# 109                          100 pier 1 place         fort worth    76102
# 110         55 east monroe street, suite 2120            chicago    60603
# 111                             80 park plaza             newark    07102
# 117               5599 san felipe, 17th floor            houston    77056
# 118     8400 east crescent parkway, suite 450  greenwood village    80111
# 120                           500 shentel way           edinburg    22824
# 122            8500 station street, suite 345             mentor    44060
# 129                        70 commerce center         greenville    29615
# 131                  37-18 northern boulevard   long island city    11101
# 142               2200 west don tyson parkway         springdale    72762
# 147             11407 cronhill drive, suite a       owings mills    21117
# 150       2600 citadel plaza drive, suite 125            houston    77008
# 160                12612 west alameda parkway           lakewood    80228
# 174               80 park plaza, p.o. box 570             newark    07102
# 176           400 atlantic street, suite 1500           stamford    06901
# 180      610 newport center drive, suite 1150      newport beach    92660
# 182             801 travis street, suite 2100            houston    77002
# 202                   531 south spring street         burlington    27215
# 219                 6220 stoneridge mall road         pleasanton    94588
# 225         309 north water street, suite 500          milwaukee    53202
# 229                          1540 drew avenue              davis    95618
# 236                      500 freeport parkway            coppell    75019
# 237          111 west 33rd street, 12th floor           new york    10120
# 243          12950 worldgate drive, suite 700            herndon    20170
# 244           495 south high street, suite 50           columbus    43215
# 257               405 park avenue, 15th floor           new york    10022
# 269            260 franklin street, suite 700             boston    02110
# 272                    7720 north dobson road         scottsdale    85256
# 275          1177 west loop south, suite 1825            houston    77027
# 281               2500 windy ridge parkway se            atlanta    30339
#
#                 closestMatchIG_add closestMatchIG_city closestMatchIG_zipcode
# 3          470 e paces ferry rd ne             atlanta                  30305
# 5          1 one williams ctr # 35               tulsa                  74172
# 9            100 constellation way           baltimore                  21202
# 23              1044 main st # 502         kansas city                  64105
# 32                  305 hartman dr             lebanon                  37087
# 37         103 john f kennedy pkwy         short hills                  07078
# 39        13900 nw science park dr            portland                  97229
# 42          26555 northwestern hwy          southfield                  48033
# 43                 1100 15th st nw          washington                  20005
# 46                909 3rd ave # 23            new york                  10022
# 69                   1600 royal st              jasper                  47546
# 70   13515 ballantyne corporate pl           charlotte                  28277
# 71             520 madison ave # b            new york                  10022
# 74                 1000 lowes blvd         mooresville                  28117
# 90                1 sw bowerman dr           beaverton                  97005
# 92                      po box 187               keene                  03431
# 94                250 sw taylor st            portland                  97204
# 98        410 n michigan ave # 400             chicago                  60611
# 99        445 broadhollow rd # 100            melville                  11747
# 100                    300 5th ave          pittsburgh                  15222
# 109  685 john b sias memorial #225          fort worth                  76134
# 110           801 w adams st # 600             chicago                  60607
# 111                    80 park plz              newark                  07102
# 117        5599 san felipe st # 17             houston                  77056
# 118     8400 e crescent pkwy # 450       greenwood vlg                  80111
# 120                500 shentel way            edinburg                  22824
# 122          8500 station st # 345              mentor                  44060
# 129                70 commerce ctr          greenville                  29615
# 131       3718 northern blvd # 600    long island city                  11101
# 142          2200 w don tyson pkwy          springdale                  72762
# 147          11407 cronhill dr # a        owings mills                  21117
# 150    2600 citadel plaza dr # 125             houston                  77008
# 160           12612 w alameda pkwy            lakewood                  80228
# 174                    80 park plz              newark                  07102
# 176           400 atlantic st # 15            stamford                  06901
# 180   610 newport center dr # 1150       newport beach                  92660
# 182           801 travis st # 2100             houston                  77002
# 202                  358 s main st          burlington                  27215
# 219        6220 stoneridge mall rd          pleasanton                  94588
# 225           309 n water st # 500           milwaukee                  53202
# 229                  1540 drew ave               davis                  95618
# 236        500 freeport pkwy # 100             coppell                  75019
# 237             111 w 33rd st # 12            new york                  10120
# 243       12950 worldgate dr # 700             herndon                  20170
# 244             495 s high st # 50            columbus                  43215
# 257              405 park ave # 15            new york                  10022
# 269          260 franklin st # 700              boston                  02110
# 272               7720 n dobson rd          scottsdale                  85256
# 275        1177 west loop s # 1825             houston                  77027
# 281       2500 windy ridge pkwy se             atlanta                  30339

# %% [markdown]
# 2x check that there are no duplicates here.

# %%
duplicates = companiesToCheck.cstatCompanies.value_counts().index[companiesToCheck.cstatCompanies.value_counts() > 1]

companiesToCheck[companiesToCheck.cstatCompanies.isin(duplicates)]
# Out:
# Empty DataFrame
# Columns: [cstatCompanies, igCompanies, cstatadd1, cstatCity, cstatZip, closestMatchIG_add, closestMatchIG_city, closestMatchIG_zipcode]
# Index: []

# %%
chqStillUnmatched = chqUnmatched[-chqUnmatched.company.isin(companiesToCheck.cstatCompanies)].reset_index(drop=True)
igStillUnmatched  = igUnmatched[-igUnmatched.company.isin(companiesToCheck.igCompanies)].reset_index(drop=True)

# companyMatches['cstatCompanies'] = chqUnmatched.company
print(chqUnmatched.shape, chqStillUnmatched.shape, companiesToCheck.shape)
print(igStillUnmatched.shape,igUnmatched.shape)
# Out:
# (769, 8) (397, 8) (372, 8)
# (57204, 7) (57570, 7)

# %%
companiesToCheck.to_csv("../../data/companyData/companiesToCheck_cityZip.csv")

# %% [markdown]
# ## Take 2
# Match remaining ones on first word of name

# %%
chqUnmatched.company[0].split(' ')[0]
# Out:
# 'prog'

# %%
chqUnmatched.company[0]
# Out:
# 'prog '

# %% [markdown]
# Get the edit distance for the first words of the company names.

# %%
companyArrayCStat = []

start = time.time()
for company in chqStillUnmatched.company:
    thisCompany = []
    for ig in igStillUnmatched.company:
        thisCompany.append(levenshtein_distance(company.split(' ')[0],ig.split(' ')[0]))
    
    companyArrayCStat.append([thisCompany])

allLD = np.concatenate(companyArrayCStat)

# %% [markdown]
# And the cosine distance.

# %%
chqStillUnmatchedFirstCo = []
igStillUnmatchedFirstCo = []

for company in chqStillUnmatched.company:
    chqStillUnmatchedFirstCo.append(company.split(' ')[0])
    
for company in igStillUnmatched.company:
    igStillUnmatchedFirstCo.append(company.split(' ')[0])

# %%
chqUnmatchedList = list(map(nlp, chqStillUnmatchedFirstCo))
allCompaniesIG = list(map(nlp, igStillUnmatchedFirstCo))


cstat = getMatrix(chqUnmatchedList)
ig    = getMatrix(allCompaniesIG)

allSimilarities = cosine_similarity(cstat,ig)

allSimilarities.shape

# largestElementsCos = (-allSimilarities).argsort(axis=-1)[:, :n]
singleLargestCos   = (-allSimilarities).argsort(axis=-1)[:, :1]

# %%
igStillUnmatched.head()
# Out:
#    index     abi                 company state             city zipcode  \
# 0     17  158329            caridian bct    co         lakewood   80401
# 1     20  211946           family brands    tn      lenoir city   37771
# 2     23  258574                    jade    pa   huntingdon vly   19006
# 3     24  262493  montana metal products    il      des plaines   60018
# 4     43  455154                     o i    tx  college station   77845
#
#                  address_line_1
# 0  14143 denver west pkwy # 200
# 1              1001 elm hill rd
# 2             3063 philmont ave
# 3                 25 howard ave
# 4                 151 graham rd

# %%
singleLargestLV   = (allLD).argsort(axis=-1)[:, :1]
# largestElementsLV = (allLD).argsort(axis=-1)[:, :n]


companyMatches2 = pd.DataFrame()
companyMatches2['cstatCompanies'] = chqStillUnmatched.company
companyMatches2['cstatadd1']      = chqStillUnmatched.cstatadd1
companyMatches2['cstatCity']      = chqStillUnmatched.cstatCity
companyMatches2['cstatState']     = chqStillUnmatched.cstatState
companyMatches2['cstatZip']       = chqStillUnmatched.cstatZipcode


for i in range(0,companyMatches2.shape[0]):
    # print(list(np.array(hq.company)[largestElements[i]]))
    companyMatches2.at[i,'misspelling']         = allLD[i,:][singleLargestLV[i]]
    companyMatches2.at[i,'levCompany']          = igStillUnmatched.company[singleLargestLV[i]].iloc[0]
    
    companyMatches2.at[i,'closestMatchIG_add']      = igStillUnmatched.address_line_1[singleLargestLV[i]].iloc[0]
    companyMatches2.at[i,'closestMatchIG_city']     = igStillUnmatched.city[singleLargestLV[i]].iloc[0]
    companyMatches2.at[i,'closestMatchIG_zipcode']  = igStillUnmatched.zipcode[singleLargestLV[i]].iloc[0]
    companyMatches2.at[i,'closestMatchIG_state']    = igStillUnmatched.state[singleLargestLV[i]].iloc[0]

    
    companyMatches2.at[i,'cosSimilarity']        = allSimilarities[i,:][singleLargestCos[i]]
    companyMatches2.at[i,'cosSimilarityCompany'] = igStillUnmatched.company[singleLargestCos[i]].iloc[0]
   
    companyMatches2.at[i,'costMatchIG_add']     = igStillUnmatched.address_line_1[singleLargestCos[i]].iloc[0]
    companyMatches2.at[i,'cosMatchIG_city']     = igStillUnmatched.city[singleLargestCos[i]].iloc[0]
    companyMatches2.at[i,'cosMatchIG_zipcode']  = igStillUnmatched.zipcode[singleLargestCos[i]].iloc[0]
    companyMatches2.at[i,'cosMatchIG_state']    = igStillUnmatched.state[singleLargestCos[i]].iloc[0]

# %%
companyMatches2.head()
# Out:
#         cstatCompanies                           cstatadd1    cstatCity  \
# 0                prog                  256 west data drive       draper
# 1  american greetings                    one american road    cleveland
# 2                  apa  2000 post oak boulevard, suite 100      houston
# 3          bard (c.r.)                  730 central avenue  murray hill
# 4   earthstone energy          633 17th street, suite 2320       denver
#
#   cstatState cstatZip  misspelling                    levCompany  \
# 0         ut    84020          1.0       pro lift indl equipment
# 1         oh    44144          0.0     american realty investors
# 2         tx    77056          0.0  apa the engineered wood assn
# 3         nj    07974          0.0         bard capital partners
# 4         co    80202          0.0             earthstone energy
#
#               closestMatchIG_add closestMatchIG_city closestMatchIG_zipcode  \
# 0             12001 plantside dr          louisville                  40299
# 1             1603 lbj fwy # 800              dallas                  75234
# 2                 7011 s 19th st              tacoma                  98466
# 3               222 greystone rd           evergreen                  80439
# 4  1400 woodloch forest dr # 300       the woodlands                  77380
#
#   closestMatchIG_state  cosSimilarity          cosSimilarityCompany  \
# 0                   ky        0.54259                  techno serve
# 1                   tx        1.00000      american central bancorp
# 2                   wa        1.00000  apa the engineered wood assn
# 3                   co        1.00000         bard capital partners
# 4                   tx        0.00000                  caridian bct
#
#                 costMatchIG_add cosMatchIG_city cosMatchIG_zipcode  \
# 0           1120 19th st nw # 8      washington              20036
# 1                3300 hedley rd     springfield              62711
# 2                7011 s 19th st          tacoma              98466
# 3              222 greystone rd       evergreen              80439
# 4  14143 denver west pkwy # 200        lakewood              80401
#
#   cosMatchIG_state
# 0               dc
# 1               il
# 2               wa
# 3               co
# 4               co

# %%
companyMatches2.shape
# Out:
# (397, 17)

# %% [markdown]
# Find if city or zip match here.

# %%
match2_cityZips = companyMatches2[(((companyMatches2.cstatCity == companyMatches2.closestMatchIG_city) | \
              (companyMatches2.cstatZip == companyMatches2.closestMatchIG_zipcode)) | \
              ((companyMatches2.cstatCity == companyMatches2.cosMatchIG_city) | \
              (companyMatches2.cstatZip == companyMatches2.cosMatchIG_zipcode)))].reset_index(drop=True)

# %%
match2_cityZips
# Out:
#                  cstatCompanies  \
# 0       colorado interstate gas
# 1            comtech telecommun
# 2         winthrop realty trust
# 3     intl flavors   fragrances
# 4                       anixter
# 5        monmouth re investment
# 6                tampa electric
# 7     virginia electric   power
# 8                westmorelandal
# 9                    tjxs (the)
# 10          herbalife nutrition
# 11   kbs real estate investment
# 12  metropolitan life insurance
# 13                      denbury
# 14                   idexx labs
# 15                    aes (the)
# 16             costco wholesale
# 17                     liquidia
# 18                gritstone bio
# 19           stabilis solutions
# 20     diamond offshre drilling
# 21      oklahoma gas   electric
# 22     enterprise finl services
# 23        capstone green energy
# 24     baltimore gas   electric
# 25                      mantech
# 26                        qwest
# 27    enlink midstream partners
# 28              auxilium pharma
# 29              usampression s
# 30                    aircastle
# 31                       domtar
# 32                       cavium
# 33          blueknight energy s
# 34           b. riley financial
# 35     cnl lifestyle properties
# 36                  kbs reit ii
# 37                servicesource
# 38          oiltanking partners
# 39     healthcare tr of america
# 40                     renesola
# 41              ocz technology
#
#                                             cstatadd1         cstatCity  \
# 0                    western pipelines, p.o. box 1087  colorado springs
# 1                    68 south service road, suite 230          melville
# 2                         7 bulfinch place, suite 500            boston
# 3                                521 west 57th street          new york
# 4                              2301 patriot boulevard          glenview
# 5   bell works complex, suite 1405, 101 crawfords ...           holmdel
# 6               teco plaza, 702 north franklin street             tampa
# 7                                 120 tredegar street          richmond
# 8                 9540 south maroon circle, suite 300         englewood
# 9                                 770 cochituate road        framingham
# 10                                       po box 80210       los angeles
# 11                800 newport center drive, suite 700     newport beach
# 12                                    200 park avenue          new york
# 13                                  5320 legacy drive             plano
# 14                                    one idexx drive         westbrook
# 15                  4300 wilson boulevard, 11th floor         arlington
# 16                                     999 lake drive          issaquah
# 17                         419 davis drive, suite 100       morrisville
# 18                      5959 horton street, suite 300        emeryville
# 19                      11750 katy freeway, suite 900           houston
# 20                      15415 katy freeway, suite 100           houston
# 21                     321 north harvey, p.o. box 321     oklahoma city
# 22                           150 north meramec avenue           clayton
# 23                                 16640 stagg street          van nuys
# 24            2 center plaza, 110 west fayette street         baltimore
# 25                          2251 corporate park drive           herndon
# 26                              100 centurylink drive            monroe
# 27                      1722 routh street, suite 1300            dallas
# 28                                       640 lee road      chesterbrook
# 29                     100 congress avenue, suite 450            austin
# 30                   201 tresser boulevard, suite 400          stamford
# 31                            234 kingsley park drive         fort mill
# 32                            2315 north first street          san jose
# 33                     6060 american plaza, suite 600             tulsa
# 34            11100 santa monica boulevard, suite 800       los angeles
# 35                            450 south orange avenue           orlando
# 36                800 newport center drive, suite 700     newport beach
# 37            707 17th street, 25th floor, suite 2500            denver
# 38                        333 clay street, suite 2400           houston
# 39             16435 north scottsdale road, suite 320        scottsdale
# 40                        850 canal street, 3rd floor          stamford
# 41                            6373 san ignacio avenue          san jose
#
#    cstatState cstatZip  misspelling                      levCompany  \
# 0          co    80944          0.0       colorado publishing house
# 1          ny    11747          0.0  comtech telecommunications crp
# 2          ma    02114          0.0       winthrop capital partners
# 3          ny    10019          0.0      intl development   envrmnt
# 4          il    60026          0.0           anixter international
# 5          nj    07733          0.0  monmouth real est invstmnt crp
# 6          fl    33602          0.0  tampa hillsborough lbrry systm
# 7          va    23219          0.0         virginia mason memorial
# 8          co    80112          2.0             westmoreland mining
# 9          ma    01701          1.0                             tjx
# 10         ca    90080          0.0    herbalife international amer
# 11         ca    92660          0.0    kbs legacy partners apt reit
# 12         ny    10166          0.0     metropolitan transportation
# 13         tx    75024          0.0               denbury resources
# 14         me    04092          0.0              idexx laboratories
# 15         va    22203          0.0                             aes
# 16         wa    98027          0.0                          costco
# 17         nc    27560          0.0           liquidia technologies
# 18         ca    94608          0.0              gritstone oncology
# 19         tx    77079          0.0                 stabilis energy
# 20         tx    77094          0.0                  diamond rental
# 21         ok    73101          0.0             oklahoma publishing
# 22         mo    63105          0.0         enterprise service dept
# 23         ca    91406          0.0                capstone turbine
# 24         md    21201          0.0               baltimore orioles
# 25         va    20171          0.0           mantech international
# 26         la    71203          1.0             west gate banshares
# 27         tx    75201          0.0                enlink midstream
# 28         pa    19087          0.0        auxilium pharmaceuticals
# 29         tx    78701          0.0           usampression partners
# 30         ct    06901          0.0               aircastle limited
# 31         sc    29715          0.0                    domtar paper
# 32         ca    95131          0.0                 cavium networks
# 33         ok    74135          0.0      blueknight energy partners
# 34         ca    90025          1.0                       b riley
# 35         fl    32801          0.0                  cnl financial
# 36         ca    92660          0.0    kbs legacy partners apt reit
# 37         co    80202          0.0     servicesource international
# 38         tx    77002          0.0            oiltanking  americas
# 39         az    85254          0.0        healthcare trust of amer
# 40         ct    06902          0.0                     renesola us
# 41         ca    95119          0.0           ocz storage solutions
#
#                 closestMatchIG_add closestMatchIG_city closestMatchIG_zipcode  \
# 0                 235 s nevada ave    colorado springs                  80903
# 1            68 s service rd # 230            melville                  11747
# 2              7 bulfinch pl # 500              boston                  02114
# 3               1173 2nd ave # 327            new york                  10065
# 4                2301 patriot blvd            glenview                  60026
# 5   101 crawfords corner rd # 1405             holmdel                  07733
# 6                  900 n ashley dr               tampa                  33602
# 7                   2811 tieton dr              yakima                  98902
# 8            9540 maroon cir # 300           englewood                  80112
# 9            770 cochituate rd # 1          framingham                  01701
# 10        800 w olympic blvd # 406         los angeles                  90015
# 11    620 newport center dr # 1300       newport beach                  92660
# 12              375 beale st # 800       san francisco                  94105
# 13                  5320 legacy dr               plano                  75024
# 14                      1 idexx dr           westbrook                  04092
# 15         4300 wilson blvd # 1100           arlington                  22203
# 16               999 lake dr # 200            issaquah                  98027
# 17              419 davis dr # 100         morrisville                  27560
# 18            5858 horton st # 210          emeryville                  94608
# 19        10375 richmond ave # 700             houston                  77042
# 20             4518 s riverside dr      salt lake city                  84123
# 21               9000 broadway ext       oklahoma city                  73114
# 22            1500 jefferson st se             olympia                  98501
# 23                  16640 stagg st            van nuys                  91406
# 24             333 w camden st # 1           baltimore                  21201
# 25          2251 corporate park dr             herndon                  20171
# 26        6003 old cheney rd # 100             lincoln                  68516
# 27            1722 routh st # 1300              dallas                  75201
# 28                      640 lee rd        chesterbrook                  19087
# 29         111 congress ave # 2400              austin                  78701
# 30          201 tresser blvd # 400            stamford                  06901
# 31            100 kingsley park dr           fort mill                  29715
# 32                   2315 n 1st st            san jose                  95131
# 33   6060 s american plaza st #600               tulsa                  74135
# 34   11100 santa monica blvd # 800         los angeles                  90025
# 35          450 s orange ave # 300             orlando                  32801
# 36    620 newport center dr # 1300       newport beach                  92660
# 37                707 17th st # 25              denver                  80202
# 38             9805 katy fwy # 400             houston                  77024
# 39     16435 n scottsdale rd # 320          scottsdale                  85254
# 40                850 canal st # 4            stamford                  06902
# 41            6373 san ignacio ave            san jose                  95119
#
#    closestMatchIG_state  cosSimilarity            cosSimilarityCompany  \
# 0                    co       1.000000     colorado retail venture svc
# 1                    ny       0.000000                    caridian bct
# 2                    ma       1.000000       winthrop capital partners
# 3                    ny       1.000000       intl matex tank terminals
# 4                    il       0.000000                    caridian bct
# 5                    nj       1.000000  monmouth real est invstmnt crp
# 6                    fl       1.000000          tampa state bankshares
# 7                    wa       1.000000  virginia secretary of cmmnwlth
# 8                    co       0.000000                    caridian bct
# 9                    ma       0.000000                    caridian bct
# 10                   ca       1.000000    herbalife international amer
# 11                   ca       1.000000    kbs legacy partners apt reit
# 12                   ca       1.000000              metropolitan bank
# 13                   tx       0.000000                    caridian bct
# 14                   me       0.000000                    caridian bct
# 15                   va       0.999999                             aes
# 16                   wa       1.000000                          costco
# 17                   nc       0.000000                    caridian bct
# 18                   ca       1.000000              gritstone oncology
# 19                   tx       0.000000                    caridian bct
# 20                   ut       1.000000            diamond mccarthy llp
# 21                   ok       1.000000     oklahoma baptist univ board
# 22                   wa       1.000000        enterprise financial svc
# 23                   ca       1.000000             capstone headwaters
# 24                   md       1.000000               baltimore orioles
# 25                   va       0.000000                    caridian bct
# 26                   ne       0.514122                     centurylink
# 27                   tx       0.000000                    caridian bct
# 28                   pa       0.000000                    caridian bct
# 29                   tx       0.000000                    caridian bct
# 30                   ct       0.000000                    caridian bct
# 31                   sc       0.000000                    caridian bct
# 32                   ca       0.000000                    caridian bct
# 33                   ok       0.000000                    caridian bct
# 34                   ca       0.666852                b   p littleford
# 35                   fl       1.000000                  cnl bancshares
# 36                   ca       1.000000    kbs legacy partners apt reit
# 37                   co       0.000000                    caridian bct
# 38                   tx       0.000000                    caridian bct
# 39                   az       1.000000      healthcare integrated tech
# 40                   ct       0.000000                    caridian bct
# 41                   ca       1.000000           ocz storage solutions
#
#                    costMatchIG_add cosMatchIG_city cosMatchIG_zipcode  \
# 0                  816 broadway st        sterling              80751
# 1     14143 denver west pkwy # 200        lakewood              80401
# 2              7 bulfinch pl # 500          boston              02114
# 3      321 saint charles ave # 200     new orleans              70130
# 4     14143 denver west pkwy # 200        lakewood              80401
# 5   101 crawfords corner rd # 1405         holmdel              07733
# 6                         326 main           tampa              67483
# 7              1111 e broad st # 4        richmond              23219
# 8     14143 denver west pkwy # 200        lakewood              80401
# 9     14143 denver west pkwy # 200        lakewood              80401
# 10        800 w olympic blvd # 406     los angeles              90015
# 11    620 newport center dr # 1300   newport beach              92660
# 12                 99 park ave # 4        new york              10016
# 13    14143 denver west pkwy # 200        lakewood              80401
# 14    14143 denver west pkwy # 200        lakewood              80401
# 15         4300 wilson blvd # 1100       arlington              22203
# 16               999 lake dr # 200        issaquah              98027
# 17    14143 denver west pkwy # 200        lakewood              80401
# 18            5858 horton st # 210      emeryville              94608
# 19    14143 denver west pkwy # 200        lakewood              80401
# 20            909 fannin st # 3700         houston              77010
# 21             500 w university st         shawnee              74804
# 22         150 n meramec ave # 350        st louis              63105
# 23             1225 17th st # 1725          denver              80202
# 24             333 w camden st # 1       baltimore              21201
# 25    14143 denver west pkwy # 200        lakewood              80401
# 26              100 centurylink dr          monroe              71203
# 27    14143 denver west pkwy # 200        lakewood              80401
# 28    14143 denver west pkwy # 200        lakewood              80401
# 29    14143 denver west pkwy # 200        lakewood              80401
# 30    14143 denver west pkwy # 200        lakewood              80401
# 31    14143 denver west pkwy # 200        lakewood              80401
# 32    14143 denver west pkwy # 200        lakewood              80401
# 33    14143 denver west pkwy # 200        lakewood              80401
# 34                   1000 hess ave         saginaw              48601
# 35          450 s orange ave # 400         orlando              32801
# 36    620 newport center dr # 1300   newport beach              92660
# 37    14143 denver west pkwy # 200        lakewood              80401
# 38    14143 denver west pkwy # 200        lakewood              80401
# 39                  1462 rudder ln       knoxville              37919
# 40    14143 denver west pkwy # 200        lakewood              80401
# 41            6373 san ignacio ave        san jose              95119
#
#    cosMatchIG_state
# 0                co
# 1                co
# 2                ma
# 3                la
# 4                co
# 5                nj
# 6                ks
# 7                va
# 8                co
# 9                co
# 10               ca
# 11               ca
# 12               ny
# 13               co
# 14               co
# 15               va
# 16               wa
# 17               co
# 18               ca
# 19               co
# 20               tx
# 21               ok
# 22               mo
# 23               co
# 24               md
# 25               co
# 26               la
# 27               co
# 28               co
# 29               co
# 30               co
# 31               co
# 32               co
# 33               co
# 34               mi
# 35               fl
# 36               ca
# 37               co
# 38               co
# 39               tn
# 40               co
# 41               ca

# %%
match2_cityZips['igCompanies'] = ''

for i in range(0,match2_cityZips.shape[0]):
    if ((match2_cityZips.cstatCity[i] == match2_cityZips.closestMatchIG_city[i]) | \
              (match2_cityZips.cstatZip[i] == match2_cityZips.closestMatchIG_zipcode[i])):
        match2_cityZips.loc[i,'igCompanies'] = match2_cityZips.levCompany[i]
    else:
        match2_cityZips.loc[i,'igCompanies'] = match2_cityZips.cosSimilarityCompany[i]

# %%
match2_cityZips[['cstatCompanies','igCompanies','closestMatchIG_add','costMatchIG_add']].shape
# Out:
# (42, 4)

# %%
match2_cityZips[['cstatCompanies','igCompanies','closestMatchIG_add','costMatchIG_add']].to_csv("../../data/companyData/match2_cityZips.csv")

# %% [markdown]
# ## Take 3
# Try the addresses here.
#
# Let's try something similar:
# - Find top 10 most similar addresses by cos sim
# - Find top 10 most similar addresses by LD
# - Find unique union of these two
# - Record LD and cos sim for each
# - Filter for totally dissimilar ones
# - ``Explode'' the dataset so we have cstat company, address
# - Find first word LD and cos sim
# - Find total LD and cos sim

# %%
n = 10

# %%
chqStillUnmatched['cstatadd1']     = chqStillUnmatched.cstatadd1.astype(str)
igStillUnmatched['address_line_1'] = igStillUnmatched.address_line_1.astype(str)

# %%
addressArrayCStat = []

start = time.time()
for address in chqStillUnmatched.cstatadd1:
    thisAddress = []
    for ig in igStillUnmatched.address_line_1:
        thisAddress.append(levenshtein_distance(str(address),str(ig)))
    
    addressArrayCStat.append([thisAddress])

allLD = np.concatenate(addressArrayCStat)

singleLargestLV   = (allLD).argsort(axis=-1)[:, :1]
largestElementsLV = (allLD).argsort(axis=-1)[:, :n]

# %%
chqUnmatchedList = list(map(nlp, chqStillUnmatched['cstatadd1']))
allCompaniesIG   = list(map(nlp, igStillUnmatched['address_line_1']))


cstat = getMatrix(chqUnmatchedList)
ig    = getMatrix(allCompaniesIG)

allSimilarities = cosine_similarity(cstat,ig)

allSimilarities.shape

singleLargestCos   = (-allSimilarities).argsort(axis=-1)[:, :1]
largestElementsCos = (-allSimilarities).argsort(axis=-1)[:, :n]

# %%
companyMatches3 = pd.DataFrame()
companyMatches3['cstatCompanies'] = chqStillUnmatched.company

# %% [markdown]
# Let's grab the set of the 10 closest addresses by LD and cos.

# %%
companyMatches3.head()
# Out:
#         cstatCompanies  closestAdds_indices
# 0                prog                   NaN
# 1  american greetings                   NaN
# 2                  apa                  NaN
# 3          bard (c.r.)                  NaN
# 4   earthstone energy                   NaN

# %% [markdown]
# Find the unique values in here.

# %%
set(largestElementsLV[i]).union(set(largestElementsCos[i]))
# Out:
# {922,
#  2060,
#  3401,
#  7689,
#  9732,
#  11623,
#  12672,
#  15080,
#  16088,
#  23186,
#  26696,
#  27546,
#  32508,
#  34245,
#  35339,
#  36426,
#  40142,
#  47201,
#  51065,
#  52646}

# %%
companyMatches3.head()
# Out:
#         cstatCompanies                                closestAdds_indices
# 0                prog   {12672, 9732, 34245, 26696, 3401, 7689, 35339,...
# 1  american greetings   {2498, 26437, 49286, 41165, 41295, 50578, 3618...
# 2                  apa  {42176, 36233, 20942, 8337, 10582, 3993, 21212...
# 3          bard (c.r.)  {20352, 34050, 24964, 53968, 39123, 51028, 555...
# 4   earthstone energy   {24516, 9669, 28361, 37579, 8981, 16471, 37852...

# %%
companyMatches3['closestAdds_indices'] = ''


for i in range(0,companyMatches3.shape[0]):
    
    # find all the closest LV and cos addresses and put them in a 
    companyMatches3.at[i,'closestAdds_indices']  = set(largestElementsLV[i]).union(set(largestElementsCos[i]))

# %% [markdown]
# And explode it so one index per line.

# %%
companyMatches3_indices = companyMatches3.explode('closestAdds_indices').reset_index(drop=True)

# %% [markdown]
# Now get the companies, the cosine similarities, and the levenshtein distances.

# %%
companyMatches3_indices.closestAdds_indices
# Out:
# 0       12672
# 1        9732
# 2       34245
# 3       26696
# 4        3401
#         ...
# 7251    56947
# 7252    27062
# 7253    53303
# 7254    53305
# 7255    32443
# Name: closestAdds_indices, Length: 7256, dtype: object

# %% [markdown]
# Get the embeddings for the cosine similarity.

# %%
for i in range(0,companyMatches3_indices.shape[0]):
    companyMatches3_indices.at[i,'igCompanies']  = igStillUnmatched.company[companyMatches3_indices.closestAdds_indices[i]] # .iloc[0]

    companyMatches3_indices.at[i,'lv']           = levenshtein_distance(companyMatches3_indices.cstatCompanies[i],companyMatches3_indices.igCompanies[i])
    companyMatches3_indices.at[i,'percMisspelled']       = companyMatches3_indices.lv[i]/len(companyMatches3_indices.cstatCompanies[i])

    # companyMatches3.at[i,'add_percMisspelled'] = companyMatches2.add_misspelling[i]/len(companyMatches2['cstatadd1'][i])

# %% [markdown]
# Get the company embeddings here.

# %%
cMatches  = companyMatches3_indices[['cstatCompanies']].drop_duplicates()
igMatches = companyMatches3_indices[['igCompanies']].drop_duplicates()

# %%
def getVector(text):
    embedding = nlp(text)
    
    return(embedding.vector)

# %%
cStatEmbeddings = list(map(getVector, cMatches.cstatCompanies))
igEmbeddings    = list(map(getVector, igMatches.igCompanies))

# %%
igMatches['igEmbedding']       = igEmbeddings
cMatches['cstatEmbedding']     = cStatEmbeddings

# %%
companyMatches3_indices = companyMatches3_indices.merge(igMatches).merge(cMatches)

# %%
companyMatches3_indices.shape
# Out:
# (7256, 7)

# %% [markdown]
# Loop through and get the cosine similarity.

# %%
for i in range(0,companyMatches3_indices.shape[0]):
    companyMatches3_indices.at[i,'cosSim']  = cosine_similarity([companyMatches3_indices.igEmbedding[i]],
                                                                [companyMatches3_indices.cstatEmbedding[i]])

# %%
filtered = companyMatches3_indices[((companyMatches3_indices.percMisspelled < 0.4) | \
                        (companyMatches3_indices.cosSim > 0.6))]

# %%
filtered[['cstatCompanies','igCompanies','percMisspelled','cosSim']].to_csv("../../data/companyData/companyMatches3_indices.csv")

# %%
filtered.shape
# Out:
# (85, 8)

# %%
filtered.head()
# Out:
#              cstatCompanies closestAdds_indices  \
# 214  monmouth re investment               22335
# 319     american greetings                31069
# 321     american greetings                20519
# 331  intl business machines               21249
# 566      lumen technologies               35266
#
#                         igCompanies    lv  percMisspelled  \
# 214  monmouth real est invstmnt crp  12.0        0.545455
# 319      american united mutual ins  14.0        0.736842
# 321              american greetings   1.0        0.052632
# 331          international business  14.0        0.636364
# 566        stealthbits technologies  10.0        0.555556
#
#                                            igEmbedding  \
# 214  [-0.283336, 0.14570001, -0.0871573, -0.2300073...
# 319  [-0.46551502, 0.14741275, 0.06110751, -0.03591...
# 321  [-0.46316501, 0.059975, -0.18294, -0.28495002,...
# 331  [-0.1470675, 0.483495, 0.28637648, -0.17117998...
# 566  [-0.23206, -0.049808, 0.158955, -0.269525, 0.0...
#
#                                         cstatEmbedding    cosSim
# 214  [-0.057172, 0.07114, 0.002073332, -0.32842332,...  0.604113
# 319  [-0.46316501, 0.059975, -0.18294, -0.28495002,...  0.674053
# 321  [-0.46316501, 0.059975, -0.18294, -0.28495002,...  1.000000
# 331  [-0.11614334, 0.24550134, 0.11403233, -0.64854...  0.712628
# 566  [0.08609001, 0.17962201, 0.191066, -0.13955499...  0.677055

# %% [markdown]
# # Combine all these things

# %%
dset1 = pd.read_csv("../../data/companyData/companiesToCheck_cityZip.csv")[['cstatCompanies','igCompanies','delete']]

# %%
dset2 = pd.read_csv("../../data/companyData/match2_cityZips.csv")[['cstatCompanies','igCompanies','delete']]

# %%
dset3 = pd.read_csv("../../data/companyData/companyMatches3_indices.csv")[['cstatCompanies','igCompanies','delete']]

# %%
dset1[['cstatCompanies','igCompanies','delete']].head()
# Out:
#                  cstatCompanies                  igCompanies  delete
# 0            american software             american software     NaN
# 1              apco oil and gas               apco oil   gas     NaN
# 2      constellation energy grp        constellation energy      NaN
# 3           central natural res    central natural resources     NaN
# 4  cracker barrel old ctry stor  cracker barrel olduntry str     NaN

# %%
dset2[['cstatCompanies','igCompanies','delete']].head()
# Out:
#               cstatCompanies                     igCompanies  delete
# 0    colorado interstate gas       colorado publishing house     NaN
# 1         comtech telecommun  comtech telecommunications crp     1.0
# 2      winthrop realty trust       winthrop capital partners     1.0
# 3  intl flavors   fragrances      intl development   envrmnt     1.0
# 4                    anixter           anixter international     NaN

# %%
dset3[['cstatCompanies','igCompanies','delete']].head()
# Out:
#     cstatCompanies                   igCompanies  delete
# 0       first data   location based technologies     1.0
# 1          albany           albany international     NaN
# 2      kbs reit ii  kbs legacy partners apt reit     NaN
# 3      ring energy     eqm technologies   energy     1.0
# 4  timios national  national alliance mental ill     1.0

# %%
cleanMerge = pd.read_csv("../../data/companyData/nameMerge.csv")[['company']].\
    rename(columns = {'company': 'cstatCompanies'})
cleanMerge['igCompanies'] = cleanMerge['cstatCompanies']

cleanMerge['delete'] = ''

print(cleanMerge.head())
# Out:
#            cstatCompanies             igCompanies delete
# 0  adc telecommunications  adc telecommunications
# 1      american airlines       american airlines
# 2   pinnacle west capital   pinnacle west capital
# 3     abbott laboratories     abbott laboratories
# 4                   aceto                   aceto

# %%
all = pd.concat([dset1,dset2,dset3,cleanMerge])
allFiltered = all[~(all.delete == 1.0)].drop_duplicates()

# %%
cleanMerge.head()
# Out:
#            cstatCompanies             igCompanies delete
# 0  adc telecommunications  adc telecommunications
# 1      american airlines       american airlines
# 2   pinnacle west capital   pinnacle west capital
# 3     abbott laboratories     abbott laboratories
# 4                   aceto                   aceto

# %%
allFiltered.shape
# Out:
# (2618, 3)

# %%
chq     = pd.read_csv("../../data/chq.csv",dtype={'cstatZipcode': 'object'}).drop(columns = {'Unnamed: 0'})

chq['cstatCompanies'] = list(map(cleanText, chq.company))
chqToMatch = chq[['cstatCompanies','gvkey']]

# %%
ig = pd.read_csv("../../data/companyData/lastHQs.csv")
ig['igCompanies'] = list(map(cleanText, ig.company))

igToMatch = ig[['igCompanies','abi']]

# %%
igToMatch.head()
# Out:
#               igCompanies     abi
# 0            caridian bct  158329
# 1           family brands  211946
# 2                    jade  258574
# 3  montana metal products  262493
# 4                     o i  455154

# %% [markdown]
# Put these all together.

# %%
gvKey_abiLinkingTable = allFiltered.merge(chqToMatch).merge(igToMatch).drop_duplicates()

# %%
gvKey_abiLinkingTable.to_csv('../../data/companyData/linkingTable.csv')

# %% [markdown]
# # Create the SC Linking Table for 2010s

# %%
c_links = pd.read_csv("../../data/companyData/compustatSCLinked.csv")

c_links['year'] = c_links.srcdate.astype('str').str.slice(0,4).astype('int64')

c_links = c_links[c_links.year > 2009][['year','gvkey','cgvkey','salecs']].\
    rename(columns = {'cgvkey': 'customer_gvkey','gvkey': 'supplier_gvkey'})




c_links.head()
# Out:
#      year  supplier_gvkey  customer_gvkey   salecs
# 80   2010            1013            9899  300.000
# 81   2010            1013            2136  146.000
# 281  2016            1094           31673   78.193
# 282  2017            1094           31673   76.598
# 283  2017            1094            7171   70.215

# %%
gvKey_abiLinkingTable = pd.read_csv('../../data/companyData/linkingTable.csv')


base_columns = gvKey_abiLinkingTable.columns 
customer_columns = "customer_" + base_columns
supplier_columns = "supplier_" + base_columns



#########################
# merge in customer information
gvKey_abiLinkingTable.columns = customer_columns

print(c_links.shape)
c_linksMerge1 = c_links.merge(gvKey_abiLinkingTable, on ='customer_gvkey')
print(c_links.shape,c_linksMerge1.shape)



#########################
# and merge in supplier 
gvKey_abiLinkingTable.columns = supplier_columns

print(c_links.shape)
c_linksMerge2 = c_linksMerge1.merge(gvKey_abiLinkingTable, on ='supplier_gvkey')
print(c_links.shape,c_linksMerge2.shape)
# Out:
# (34473, 4)
# (34473, 4) (24295, 9)
# (34473, 4)
# (34473, 4) (20544, 14)

# %%
c_linksMerge2.to_csv("../../data/companyData/clinks_IG_selected.csv")

# %%
gvKey_abiLinkingTable
# Out:
#       supplier_Unnamed: 0       supplier_cstatCompanies  \
# 0                       0            american software
# 1                       1              apco oil and gas
# 2                       2      constellation energy grp
# 3                       3           central natural res
# 4                       4  cracker barrel old ctry stor
# ...                   ...                           ...
# 2654                 2654       cdti advanced materials
# 2655                 2655                    futurefuel
# 2656                 2656  lyondellbasell industries nv
# 2657                 2657                       doriang
# 2658                 2658                        arcosa
#
#               supplier_igCompanies  supplier_delete  supplier_gvkey  \
# 0                american software              NaN            1562
# 1                   apco oil   gas              NaN            1682
# 2            constellation energy               NaN            1995
# 3        central natural resources              NaN            2852
# 4      cracker barrel olduntry str              NaN            3570
# ...                            ...              ...             ...
# 2654       cdti advanced materials              NaN          282553
# 2655                    futurefuel              NaN          287462
# 2656  lyondellbasell industries nv              NaN          294524
# 2657                       doriang              NaN          317264
# 2658                        arcosa              NaN          328795
#
#       supplier_abi
# 0          4378204
# 1        544813678
# 2        506384064
# 3        312712631
# 4        852053057
# ...            ...
# 2654     967328568
# 2655     679546432
# 2656     200051589
# 2657     435494175
# 2658     739118540
#
# [2659 rows x 6 columns]

# %% [markdown]
# This is probably because: (1) companies are not in North America, or (2) companies are not in the physical goods industries we're interested in. We can verify this though: look at c_links where both the customer and supplier are in the dataset of interest.

# %%
c_linkTest = c_links[c_links.customer_gvkey.isin(chq.gvkey.unique()) & \
                     c_links.supplier_gvkey.isin(chq.gvkey.unique())]
print("Percent of firms with a match: ", c_linksMerge2.shape[0]/c_linkTest.shape[0])
# Out:
# Percent of firms with a match:  0.8768620086217935

# %% [markdown]
# It's entirely possible that we have too small of a sample from the 2010s alone. Let's just try it though and see how it goes.
#
# First, make a sample with the companies on three years of either side of when it reports another customer.

# %%
scTableCustomers = c_linksMerge2.copy()[['year','customer_gvkey','customer_abi']]
scTableSuppliers = c_linksMerge2.copy()[['year','supplier_gvkey','supplier_abi']]

# %%
scTableCustomers.head()
# Out:
#    year  customer_gvkey  customer_abi
# 0  2010            9899     460637358
# 1  2010            2136       7564776
# 2  2010            9899     460637358
# 3  2011            9899     460637358
# 4  2012            9899     460637358

# %%
def makeThreeEitherSide(df): 
    yrPlus1 = df.copy(); yrPlus1['year'] += 1
    yrPlus2 = df.copy(); yrPlus2['year'] += 1
    yrPlus3 = df.copy(); yrPlus3['year'] += 1
    
    yrMinus1 = df.copy(); yrMinus1['year'] -= 1
    yrMinus2 = df.copy(); yrMinus2['year'] -= 1
    yrMinus3 = df.copy(); yrMinus3['year'] -= 1
    
    all = pd.concat([yrPlus1,yrPlus2,yrPlus3,yrMinus1,yrMinus2,yrMinus3])
    
    return(all)

# %%
allCustomerData = makeThreeEitherSide(scTableCustomers)
allCustomerData.columns = ['year','gvkey','abi']


allSupplierData = makeThreeEitherSide(scTableSuppliers)
allSupplierData.columns = ['year','gvkey','abi']

# %%
allSupplierData.year
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2012
# 4        2013
#          ...
# 20539    2014
# 20540    2015
# 20541    2016
# 20542    2017
# 20543    2018
# Name: year, Length: 123264, dtype: int64

# %%
allAbi = allCustomerData.abi.append(allSupplierData.abi).drop_duplicates()

# %%
hqsOnly = pd.read_csv("../../data/ig2010s_uniqueHQs.csv").drop(columns = {'Unnamed: 0'})

# %%
hqsOnly.head()
# Out:
#      abi                         company
# 0   7609            SOLITRON DEVICES INC
# 1  21311   WESTERN STATES ENVELOPE & LBL
# 2  29603                THIELE KAOLIN CO
# 3  71340                 TRI STAFF GROUP
# 4  77743  NATIONAL TECHNICAL SYSTEMS INC

# %%
hq = pd.read_csv("../../data/ig2010s_uniqueHQs_multLocations.csv").\
    drop(columns = {'Unnamed: 0'}).\
    rename(columns = {'archive_version_year': 'year'})

hq['year'] = hq.year.astype('int64')

hqRelevant = hq[hq.abi.isin(allAbi)]

# %%
hqRelevant[hqRelevant.abi == 71340]
# Out:
# Empty DataFrame
# Columns: [abi, ticker, company, year, state, city, address_line_1, zipcode, latitude, longitude]
# Index: []

# %%
allSupplierData = allSupplierData.merge(hqRelevant).drop_duplicates()
allCustomerData = allCustomerData.merge(hqRelevant).drop_duplicates()

# %%
allCustomerData.to_csv("../../data/companyData/allCustomerData.csv")
allSupplierData.to_csv("../../data/companyData/allSupplierData.csv")

# %%
allSupplierData.shape
# Out:
# (9612, 11)

# %%
hqsOnly = pd.read_csv("../../data/ig2010s_uniqueHQs.csv")

# %%
allAbi.isin(hqsOnly.abi)
# Out:
# 0        True
# 1        True
# 12       True
# 14       True
# 19       True
#          ...
# 20517    True
# 20525    True
# 20527    True
# 20529    True
# 20532    True
# Name: abi, Length: 2390, dtype: bool

# %%
hq.head()
# Out:
#      abi ticker                         company  year state             city  \
# 0   7609   SODI            SOLITRON DEVICES INC  2010    FL  WEST PALM BEACH
# 1  21311    NaN   WESTERN STATES ENVELOPE & LBL  2010    WI           BUTLER
# 2  29603    NaN                THIELE KAOLIN CO  2010    GA     SANDERSVILLE
# 3  71340    NaN                 TRI STAFF GROUP  2010    CA        SAN DIEGO
# 4  77743    NaN  NATIONAL TECHNICAL SYSTEMS INC  2010    CA        CALABASAS
#
#              address_line_1  zipcode  latitude  longitude
# 0  3301 ELECTRONICS WAY # C    33407  26.74120  -80.06694
# 1           4480 N 132ND ST    53007  43.09799  -88.07399
# 2             520 KAOLIN RD    31082  32.96893  -82.81953
# 3   6336 GREENWICH DR # 100    92122  32.85445 -117.18594
# 4  24007 VENTURA BLVD # 200    91302  34.15562 -118.65163
